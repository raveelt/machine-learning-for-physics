# %% [markdown]
# # Lab Notebook 20
#
# In this notebook, we use a fully connected neural network to solve a previously seen problem in regression: the photometric redshift problem  We also explore the effect of loss function and learning rate schedule.
#
# *Modified from: Copyright: Viviana Acquaviva (2023). License: [BSD-3-clause](https://opensource.org/license/bsd-3-clause/)*

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
import keras

from keras.optimizers import Adam
from keras.models import Sequential #the model is built adding layers one after the other
from keras.layers import Dense #fully connected layers: every output talks to every input
from keras.layers import Dropout #for regularization

# %% [markdown]
# # Part 1: PhotoZ regression with a deep NN

# %% [markdown]
# ## Step 1

# %% [markdown]
# Let us begin with the reduced (high-quality) data set we used for Bagging and Boosting methods. For reference, our best model achieved an outlier fraction of 4%.
#
# Read in 'sel_features.csv' and 'sel_target.csv' as X and y, respectively. You will need to shuffle X and y (use random_state=12) as we did in the previous notebook.

# %%
features = pd.read_csv('/Users/erinbennett/Downloads/sel_features (1).csv', delimiter='\t')
target = pd.read_csv('/Users/erinbennett/Downloads/sel_target (1).csv')

X, y = shuffle(features, target, random_state=12)

# %%
print(X.shape)
X.head()
# Out:
# (6307, 6)
#       u_apercor  g_apercor  r_apercor  i_apercor  z_apercor  y_apercor
# 4561    23.7774    23.4961    23.2445    22.9700    22.5860    22.4497
# 3675    23.7430    23.3638    22.6674    21.7934    21.2195    21.0882
# 3201    24.1826    23.1667    22.6836    22.4811    22.3890    22.4926
# 780     23.6480    23.2737    22.6016    22.3798    22.3236    22.3666
# 4205    24.0790    23.7875    23.3592    22.6754    22.4678    22.4220

# %%
print(y.shape)
y.head()
# Out:
# (6307, 1)
#       zhelio
# 4561  1.3944
# 3675  0.9846
# 3201  0.1683
# 780   0.4280
# 4205  0.8421

# %% [markdown]
# Divide the data into fifths; we would like to use a 60/20/20 split for training/validation/test. Define these arrays.

# %%
X_train, X_val, X_test = X[:3784], X[3784:5046], X[5046:]
y_train, y_val, y_test = y[:3784], y[3784:5046], y[5046:]

X_train.shape, X_val.shape, X_test.shape, y_train.shape, y_val.shape, y_test.shape
# Out:
# ((3784, 6), (1262, 6), (1261, 6), (3784, 1), (1262, 1), (1261, 1))

# %% [markdown]
# We know that we need to scale our data! Do so below:

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Step 2
#
# In a regression problem, we will choose a different activation for the output layer (linear), and an appropriate loss function (MSE). Our input layer has **six neurons** for this problem. For other parameters and the network structure, we can start with two relu-activated layers with **100 neurons** and go from there.
#
# 1. Define your model using "Sequential()".
# 2. Define your optimizer using the Adam optimizer from keras, and use the default learning rate of 0.001.
# 3. Add an input layer and specify a size of 100 neurons (size=number of original features).
# 4. Add one hidden layer and specify 100 neurons.
# 5. Add an output layer with one neuron
# 6. Finally, compile your model using MSE as the loss.

# %%
model = Sequential()

model.add(Dense(100, input_dim=X_train_scaled.shape[1], activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(1, activation='linear'))

model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# %% [markdown]
# To create your neural network, fit your model and use 100 epochs and batch size = 300:

# %%
history = model.fit(X_train_scaled, y_train,
                    epochs=100,
                    batch_size=300,
                    validation_data=(X_val_scaled, y_val))
# Out:
# Epoch 1/100
# 13/13 [==============================] - 1s 10ms/step - loss: 0.3227 - val_loss: 0.2004
# Epoch 2/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1617 - val_loss: 0.1033
# Epoch 3/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0873 - val_loss: 0.0586
# Epoch 4/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0609 - val_loss: 0.0418
# Epoch 5/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0506 - val_loss: 0.0359
# Epoch 6/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0475 - val_loss: 0.0343
# Epoch 7/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0456 - val_loss: 0.0327
# Epoch 8/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0442 - val_loss: 0.0324
# Epoch 9/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0434 - val_loss: 0.0321
# Epoch 10/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0424 - val_loss: 0.0304
# Epoch 11/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0417 - val_loss: 0.0305
# Epoch 12/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0405 - val_loss: 0.0294
# Epoch 13/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0397 - val_loss: 0.0303
# Epoch 14/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0393 - val_loss: 0.0293
# Epoch 15/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0390 - val_loss: 0.0292
# Epoch 16/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0388 - val_loss: 0.0283
# Epoch 17/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0380 - val_loss: 0.0290
# Epoch 18/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0374 - val_loss: 0.0291
# Epoch 19/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0373 - val_loss: 0.0285
# Epoch 20/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0369 - val_loss: 0.0282
# Epoch 21/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0364 - val_loss: 0.0281
# Epoch 22/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0368 - val_loss: 0.0277
# Epoch 23/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0361 - val_loss: 0.0283
# Epoch 24/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0355 - val_loss: 0.0277
# Epoch 25/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0356 - val_loss: 0.0274
# Epoch 26/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0354 - val_loss: 0.0272
# Epoch 27/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0353 - val_loss: 0.0280
# Epoch 28/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0353 - val_loss: 0.0270
# Epoch 29/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0342 - val_loss: 0.0263
# Epoch 30/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0338 - val_loss: 0.0265
# Epoch 31/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0338 - val_loss: 0.0268
# Epoch 32/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0333 - val_loss: 0.0261
# Epoch 33/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0333 - val_loss: 0.0267
# Epoch 34/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0335 - val_loss: 0.0262
# Epoch 35/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0335 - val_loss: 0.0255
# Epoch 36/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0328 - val_loss: 0.0282
# Epoch 37/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0335 - val_loss: 0.0264
# Epoch 38/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0324 - val_loss: 0.0257
# Epoch 39/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0316 - val_loss: 0.0255
# Epoch 40/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0318 - val_loss: 0.0272
# Epoch 41/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0319 - val_loss: 0.0259
# Epoch 42/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0315 - val_loss: 0.0261
# Epoch 43/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0312 - val_loss: 0.0263
# Epoch 44/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0313 - val_loss: 0.0277
# Epoch 45/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0313 - val_loss: 0.0280
# Epoch 46/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0313 - val_loss: 0.0253
# Epoch 47/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0306 - val_loss: 0.0255
# Epoch 48/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0310 - val_loss: 0.0254
# Epoch 49/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0316 - val_loss: 0.0263
# Epoch 50/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0309 - val_loss: 0.0248
# Epoch 51/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0295 - val_loss: 0.0244
# Epoch 52/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0293 - val_loss: 0.0256
# Epoch 53/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0297 - val_loss: 0.0257
# Epoch 54/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0301 - val_loss: 0.0243
# Epoch 55/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0305 - val_loss: 0.0240
# Epoch 56/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0289 - val_loss: 0.0255
# Epoch 57/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0300 - val_loss: 0.0271
# Epoch 58/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0287 - val_loss: 0.0245
# Epoch 59/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0281 - val_loss: 0.0239
# Epoch 60/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0278 - val_loss: 0.0238
# Epoch 61/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0281 - val_loss: 0.0237
# Epoch 62/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0275 - val_loss: 0.0235
# Epoch 63/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0279 - val_loss: 0.0251
# Epoch 64/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0279 - val_loss: 0.0240
# Epoch 65/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0282 - val_loss: 0.0256
# Epoch 66/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0273 - val_loss: 0.0233
# Epoch 67/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0269 - val_loss: 0.0232
# Epoch 68/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0264 - val_loss: 0.0236
# Epoch 69/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0264 - val_loss: 0.0236
# Epoch 70/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0266 - val_loss: 0.0241
# Epoch 71/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0271 - val_loss: 0.0247
# Epoch 72/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0273 - val_loss: 0.0234
# Epoch 73/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0263 - val_loss: 0.0240
# Epoch 74/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0263 - val_loss: 0.0236
# Epoch 75/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0261 - val_loss: 0.0230
# Epoch 76/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0259 - val_loss: 0.0235
# Epoch 77/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0254 - val_loss: 0.0227
# Epoch 78/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0251 - val_loss: 0.0233
# Epoch 79/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0251 - val_loss: 0.0235
# Epoch 80/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0250 - val_loss: 0.0230
# Epoch 81/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0253 - val_loss: 0.0229
# Epoch 82/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0246 - val_loss: 0.0230
# Epoch 83/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0247 - val_loss: 0.0224
# Epoch 84/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0244 - val_loss: 0.0234
# Epoch 85/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0248 - val_loss: 0.0229
# Epoch 86/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0245 - val_loss: 0.0235
# Epoch 87/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0246 - val_loss: 0.0238
# Epoch 88/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0243 - val_loss: 0.0218
# Epoch 89/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0240 - val_loss: 0.0234
# Epoch 90/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0242 - val_loss: 0.0223
# Epoch 91/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0237 - val_loss: 0.0223
# Epoch 92/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0232 - val_loss: 0.0222
# Epoch 93/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0235 - val_loss: 0.0225
# Epoch 94/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0237 - val_loss: 0.0223
# Epoch 95/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0237 - val_loss: 0.0219
# Epoch 96/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0231 - val_loss: 0.0231
# Epoch 97/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0232 - val_loss: 0.0218
# Epoch 98/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0227 - val_loss: 0.0215
# Epoch 99/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0227 - val_loss: 0.0225
# Epoch 100/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0230 - val_loss: 0.0221

# %% [markdown]
# Use "model.evaluate" to find the MSE:

# %%
mse = model.evaluate(X_test_scaled, y_test)
print("Mean Squared Error on Test Set:", mse)
# Out:
# 40/40 [==============================] - 0s 712us/step - loss: 0.0261
# Mean Squared Error on Test Set: 0.026107031852006912

# %% [markdown]
# ## Step 3
#
# As in the previous lab, we can plot the loss as a function of epoch from the train and validation data sets. Here the loss is of course the MSE.

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Mean Squared Error')
plt.title('MSE Loss')
plt.legend()
plt.show()

# %% [markdown]
# As always with regression problems, it is helpful to plot the predictions against the true values. Plot estimated redshift versus true redshift in a scatter plot below:

# %%
y_pred = model.predict(X_test_scaled)

plt.scatter(y_test, y_pred, color='blue', alpha=0.5)
plt.xlabel('True Redshift')
plt.ylabel('Predicted Redshift')
plt.title('True Redshift vs Predicted Redshift')
plt.show()
# Out:
# 40/40 [==============================] - 0s 704us/step

# %% [markdown]
# ## Step 4
#
# We didn't do cross validation, so we can only generate predictions on our single test fold in order to derive the other metrics we are interested in.
#
# First, calculate the Outlier Fraction (OLF):
#
# $\mathrm{OLF} = \mathrm{num}\left ( \frac{|\Delta z|}{1+z_{\mathrm{true}}} > 0.15 = \mathrm{true} \right)/N$
#
# *The numerator is the number of instances where $\frac{|\Delta z|}{1+z_{\mathrm{true}}}>0.15$ is true. $N$ is the length of $y_{\mathrm{test}}$.*
#
# We can also calculate the Normalized Median Absolute Deviation (NMAD):
#
# $\sigma_{\mathrm{NMAD}}=1.48 \times \mathrm{median}\left ( \frac{|\Delta z|}{1+z_{\mathrm{true}}}\right )$

# %%
delta_z = np.abs(y_pred - y_test)

outlier_frac_mse = np.sum(delta_z/(1+y_test) > 0.15) / len(y_test)
nmad_mse = 1.48 * np.median(delta_z/(1+y_test))

print("Outlier Fraction:", float(outlier_frac_mse))
print("NMAD:", nmad_mse)
# Out:
# Outlier Fraction: 0.04916732751784298
# NMAD: 0.0350407948670011

# %% [markdown]
# # Part 2: Effect of loss function
#
# So far, we have used the MSE loss in our training, but this choice is not unique. Would using the MAE or MAPE loss functions give better results for the OLF and NMAD parameters?

# %% [markdown]
# ### MAPE loss does

# %%
# MSE
print("Outlier Fraction:", float(outlier_frac_mse))
print("NMAD:", nmad_mse)
# Out:
# Outlier Fraction: 0.04916732751784298
# NMAD: 0.0350407948670011

# %%
# MAE
history_mae = model.fit(X_train_scaled, y_train,
                         epochs=100,
                         batch_size=300,
                         validation_data=(X_val_scaled, y_val))

model.compile(optimizer=Adam(learning_rate=0.001), loss='MeanAbsoluteError')
# Out:
# Epoch 1/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0227 - val_loss: 0.0225
# Epoch 2/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0233 - val_loss: 0.0254
# Epoch 3/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0233 - val_loss: 0.0220
# Epoch 4/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0222 - val_loss: 0.0238
# Epoch 5/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0223 - val_loss: 0.0221
# Epoch 6/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0222 - val_loss: 0.0239
# Epoch 7/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0227 - val_loss: 0.0217
# Epoch 8/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0221 - val_loss: 0.0219
# Epoch 9/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0217 - val_loss: 0.0221
# Epoch 10/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0217 - val_loss: 0.0213
# Epoch 11/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0217 - val_loss: 0.0221
# Epoch 12/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0216 - val_loss: 0.0220
# Epoch 13/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0216 - val_loss: 0.0224
# Epoch 14/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0214 - val_loss: 0.0216
# Epoch 15/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0214 - val_loss: 0.0223
# Epoch 16/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0210 - val_loss: 0.0216
# Epoch 17/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0211 - val_loss: 0.0220
# Epoch 18/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0212 - val_loss: 0.0229
# Epoch 19/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0209 - val_loss: 0.0219
# Epoch 20/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0205 - val_loss: 0.0221
# Epoch 21/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0210 - val_loss: 0.0217
# Epoch 22/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0204 - val_loss: 0.0219
# Epoch 23/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0207 - val_loss: 0.0222
# Epoch 24/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0206 - val_loss: 0.0224
# Epoch 25/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0204 - val_loss: 0.0220
# Epoch 26/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0202 - val_loss: 0.0214
# Epoch 27/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0198 - val_loss: 0.0222
# Epoch 28/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0205 - val_loss: 0.0224
# Epoch 29/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0201 - val_loss: 0.0218
# Epoch 30/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0202 - val_loss: 0.0226
# Epoch 31/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0208 - val_loss: 0.0222
# Epoch 32/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0201 - val_loss: 0.0211
# Epoch 33/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0197 - val_loss: 0.0219
# Epoch 34/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0198 - val_loss: 0.0220
# Epoch 35/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0200 - val_loss: 0.0228
# Epoch 36/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0196 - val_loss: 0.0223
# Epoch 37/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0200 - val_loss: 0.0219
# Epoch 38/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0207 - val_loss: 0.0230
# Epoch 39/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0197 - val_loss: 0.0223
# Epoch 40/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0200 - val_loss: 0.0215
# Epoch 41/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0190 - val_loss: 0.0214
# Epoch 42/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0191 - val_loss: 0.0224
# Epoch 43/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0194 - val_loss: 0.0222
# Epoch 44/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0197 - val_loss: 0.0221
# Epoch 45/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0192 - val_loss: 0.0227
# Epoch 46/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0197 - val_loss: 0.0240
# Epoch 47/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0218 - val_loss: 0.0228
# Epoch 48/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0201 - val_loss: 0.0219
# Epoch 49/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0190 - val_loss: 0.0221
# Epoch 50/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0187 - val_loss: 0.0220
# Epoch 51/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0188 - val_loss: 0.0217
# Epoch 52/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0188 - val_loss: 0.0211
# Epoch 53/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0187 - val_loss: 0.0225
# Epoch 54/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0183 - val_loss: 0.0227
# Epoch 55/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0185 - val_loss: 0.0212
# Epoch 56/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0186 - val_loss: 0.0220
# Epoch 57/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0184 - val_loss: 0.0233
# Epoch 58/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0187 - val_loss: 0.0220
# Epoch 59/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0181 - val_loss: 0.0207
# Epoch 60/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0182 - val_loss: 0.0210
# Epoch 61/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0183 - val_loss: 0.0221
# Epoch 62/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0183 - val_loss: 0.0227
# Epoch 63/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0184 - val_loss: 0.0218
# Epoch 64/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0182 - val_loss: 0.0214
# Epoch 65/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0181 - val_loss: 0.0214
# Epoch 66/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0174 - val_loss: 0.0214
# Epoch 67/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0176 - val_loss: 0.0212
# Epoch 68/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0175 - val_loss: 0.0208
# Epoch 69/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0177 - val_loss: 0.0212
# Epoch 70/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0186 - val_loss: 0.0213
# Epoch 71/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0174 - val_loss: 0.0209
# Epoch 72/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0174 - val_loss: 0.0215
# Epoch 73/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0177 - val_loss: 0.0217
# Epoch 74/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0176 - val_loss: 0.0223
# Epoch 75/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0176 - val_loss: 0.0210
# Epoch 76/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0181 - val_loss: 0.0225
# Epoch 77/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0172 - val_loss: 0.0214
# Epoch 78/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0177 - val_loss: 0.0209
# Epoch 79/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0172 - val_loss: 0.0207
# Epoch 80/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0172 - val_loss: 0.0212
# Epoch 81/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0168 - val_loss: 0.0211
# Epoch 82/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0167 - val_loss: 0.0212
# Epoch 83/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0170 - val_loss: 0.0209
# Epoch 84/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0166 - val_loss: 0.0215
# Epoch 85/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0173 - val_loss: 0.0212
# Epoch 86/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0167 - val_loss: 0.0225
# Epoch 87/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0165 - val_loss: 0.0208
# Epoch 88/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0162 - val_loss: 0.0207
# Epoch 89/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0163 - val_loss: 0.0219
# Epoch 90/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0179 - val_loss: 0.0221
# Epoch 91/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0166 - val_loss: 0.0207
# Epoch 92/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0165 - val_loss: 0.0213
# Epoch 93/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0167 - val_loss: 0.0210
# Epoch 94/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0164 - val_loss: 0.0237
# Epoch 95/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0170 - val_loss: 0.0216
# Epoch 96/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0164 - val_loss: 0.0207
# Epoch 97/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0160 - val_loss: 0.0217
# Epoch 98/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0167 - val_loss: 0.0224
# Epoch 99/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0167 - val_loss: 0.0208
# Epoch 100/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0169 - val_loss: 0.0212

# %%
mse_mae = model.evaluate(X_test_scaled, y_test)

y_pred_mae = model.predict(X_test_scaled)
delta_z_mae = np.abs(y_pred_mae - y_test)
outlier_frac_mae = np.sum(delta_z_mae / (1 + y_test) > 0.15) / len(y_test)
nmad_mae = 1.48 * np.median(delta_z_mae / (1 + y_test))

print("Outlier Fraction:", float(outlier_frac_mae))
print("NMAD:", nmad_mae)
# Out:
# 40/40 [==============================] - 0s 931us/step - loss: 0.0762
# 40/40 [==============================] - 0s 675us/step
# Outlier Fraction: 0.03885804916732752
# NMAD: 0.03831100678568738

# %%
# MAPE
history_mape = model.fit(X_train_scaled, y_train,
                         epochs=100,
                         batch_size=300,
                         validation_data=(X_val_scaled, y_val))

model.compile(optimizer=Adam(learning_rate=0.001), loss='MeanAbsolutePercentageError')
# Out:
# Epoch 1/100
# 13/13 [==============================] - 1s 7ms/step - loss: 0.0867 - val_loss: 0.0740
# Epoch 2/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0673 - val_loss: 0.0675
# Epoch 3/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0627 - val_loss: 0.0614
# Epoch 4/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0598 - val_loss: 0.0612
# Epoch 5/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0600 - val_loss: 0.0604
# Epoch 6/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0597 - val_loss: 0.0612
# Epoch 7/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0605 - val_loss: 0.0614
# Epoch 8/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0602 - val_loss: 0.0615
# Epoch 9/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0598 - val_loss: 0.0626
# Epoch 10/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0590 - val_loss: 0.0586
# Epoch 11/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0580 - val_loss: 0.0590
# Epoch 12/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0576 - val_loss: 0.0597
# Epoch 13/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0597 - val_loss: 0.0597
# Epoch 14/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0583 - val_loss: 0.0586
# Epoch 15/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0575 - val_loss: 0.0602
# Epoch 16/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0582 - val_loss: 0.0586
# Epoch 17/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0581 - val_loss: 0.0585
# Epoch 18/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0581 - val_loss: 0.0597
# Epoch 19/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0588 - val_loss: 0.0574
# Epoch 20/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0577 - val_loss: 0.0589
# Epoch 21/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0569 - val_loss: 0.0600
# Epoch 22/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0578 - val_loss: 0.0584
# Epoch 23/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0576 - val_loss: 0.0611
# Epoch 24/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0594 - val_loss: 0.0578
# Epoch 25/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0573 - val_loss: 0.0613
# Epoch 26/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0588 - val_loss: 0.0573
# Epoch 27/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0564 - val_loss: 0.0560
# Epoch 28/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0568 - val_loss: 0.0582
# Epoch 29/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0567 - val_loss: 0.0580
# Epoch 30/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0580 - val_loss: 0.0552
# Epoch 31/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0572 - val_loss: 0.0630
# Epoch 32/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0591 - val_loss: 0.0567
# Epoch 33/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0589 - val_loss: 0.0586
# Epoch 34/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0583 - val_loss: 0.0570
# Epoch 35/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0567 - val_loss: 0.0574
# Epoch 36/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0565 - val_loss: 0.0582
# Epoch 37/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0552 - val_loss: 0.0553
# Epoch 38/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0546 - val_loss: 0.0557
# Epoch 39/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0539 - val_loss: 0.0549
# Epoch 40/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0542 - val_loss: 0.0547
# Epoch 41/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0546 - val_loss: 0.0552
# Epoch 42/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0548 - val_loss: 0.0564
# Epoch 43/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0569 - val_loss: 0.0555
# Epoch 44/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0584 - val_loss: 0.0595
# Epoch 45/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0560 - val_loss: 0.0538
# Epoch 46/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0543 - val_loss: 0.0547
# Epoch 47/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0547 - val_loss: 0.0543
# Epoch 48/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0537 - val_loss: 0.0534
# Epoch 49/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0540 - val_loss: 0.0544
# Epoch 50/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0552 - val_loss: 0.0570
# Epoch 51/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0547 - val_loss: 0.0556
# Epoch 52/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0543 - val_loss: 0.0532
# Epoch 53/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0538 - val_loss: 0.0548
# Epoch 54/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0551 - val_loss: 0.0584
# Epoch 55/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0555 - val_loss: 0.0572
# Epoch 56/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0546 - val_loss: 0.0547
# Epoch 57/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0545 - val_loss: 0.0530
# Epoch 58/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0531 - val_loss: 0.0524
# Epoch 59/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0537 - val_loss: 0.0536
# Epoch 60/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0544 - val_loss: 0.0542
# Epoch 61/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0551 - val_loss: 0.0562
# Epoch 62/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0558 - val_loss: 0.0532
# Epoch 63/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0533 - val_loss: 0.0533
# Epoch 64/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0525 - val_loss: 0.0529
# Epoch 65/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0542 - val_loss: 0.0556
# Epoch 66/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0543 - val_loss: 0.0540
# Epoch 67/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0536 - val_loss: 0.0552
# Epoch 68/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0525 - val_loss: 0.0526
# Epoch 69/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0514 - val_loss: 0.0531
# Epoch 70/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0518 - val_loss: 0.0518
# Epoch 71/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0515 - val_loss: 0.0536
# Epoch 72/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0519 - val_loss: 0.0552
# Epoch 73/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0519 - val_loss: 0.0530
# Epoch 74/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0535 - val_loss: 0.0522
# Epoch 75/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0532 - val_loss: 0.0517
# Epoch 76/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0518 - val_loss: 0.0514
# Epoch 77/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0520 - val_loss: 0.0519
# Epoch 78/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0521 - val_loss: 0.0540
# Epoch 79/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0516 - val_loss: 0.0517
# Epoch 80/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0524 - val_loss: 0.0530
# Epoch 81/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0514 - val_loss: 0.0530
# Epoch 82/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0516 - val_loss: 0.0522
# Epoch 83/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0529 - val_loss: 0.0522
# Epoch 84/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0523 - val_loss: 0.0527
# Epoch 85/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0517 - val_loss: 0.0523
# Epoch 86/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0535 - val_loss: 0.0525
# Epoch 87/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0514 - val_loss: 0.0533
# Epoch 88/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0512 - val_loss: 0.0533
# Epoch 89/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0516 - val_loss: 0.0550
# Epoch 90/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0523 - val_loss: 0.0517
# Epoch 91/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0512 - val_loss: 0.0515
# Epoch 92/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0518 - val_loss: 0.0512
# Epoch 93/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0525 - val_loss: 0.0521
# Epoch 94/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0509 - val_loss: 0.0535
# Epoch 95/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0514 - val_loss: 0.0519
# Epoch 96/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0513 - val_loss: 0.0517
# Epoch 97/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0507 - val_loss: 0.0516
# Epoch 98/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0519 - val_loss: 0.0557
# Epoch 99/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0542 - val_loss: 0.0540
# Epoch 100/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0511 - val_loss: 0.0518

# %%
mse_mape = model.evaluate(X_test_scaled, y_test)

y_pred_mape = model.predict(X_test_scaled)
delta_z_mape = np.abs(y_pred_mape - y_test)
outlier_frac_mape = np.sum(delta_z_mape / (1 + y_test) > 0.15) / len(y_test)
nmad_mape = 1.48 * np.median(delta_z_mape / (1 + y_test))

print("Outlier Fraction:", float(outlier_frac_mape))
print("NMAD:", nmad_mape)
# Out:
# 40/40 [==============================] - 0s 870us/step - loss: 13.4199
# 40/40 [==============================] - 0s 842us/step
# Outlier Fraction: 0.025376685170499604
# NMAD: 0.024497887710661255

# %% [markdown]
# # Part 3: Effect of learning rate schedules
#
# When training a neural network, we can tune the performance by optimizing a large set of hyperparameters. Last time, we looked at the choice of optimizer and regularization. Another important parameter is the learning rate. A learning rate that is set too small will slow down the training, as we update the weights of the network in tiny steps. On the other hand, if the learning rate is set too high, the training can diverge. Usually we want to start with a large learning rate to make fast progress and then slow down the training close to the optimum. This can be achieved by using learning rate schedules, which we will investigate in this exercise.

# %% [markdown]
# ## Step 1: Time based-decay
#
# First we can try a time-based decay:
# $$\eta(t)=\eta_0/(1+t⋅\eta_0/n_{epochs})$$
#
# where $\eta_0$ is the initial learning rate, $t$ the iteration number (epoch) and $n_{epochs}$ the total number of epochs.
#
# Write a function (i.e the learning schedule) that implements this learning schedule. The function takes an epoch index (integer, indexed from 0) and current learning rate (float) as inputs and returns a new learning rate as output (float). In our case, the current learning rate is not actually used in the function, but this format is expected when we use it in keras later. Set the initial learning rate to 0.001 and the number of epochs to 100. Make a plot of the learning rate as a function of epochs.

# %%
def time_based_decay(epoch, lr):
    initial_lr = 0.001
    epochs = 100
    decay_rate = initial_lr / epochs
    new_lr = initial_lr / (1 + epoch * decay_rate)
    return new_lr

# %%
epochs = np.arange(100)
lr = 0.001
learning_rates = [time_based_decay(epoch, lr) for epoch in epochs]

plt.plot(epochs, learning_rates)
plt.xlabel('Epoch')
plt.ylabel('Learning Rate')
plt.title('Time-based Decay Learning Rate Schedule')
plt.show()

# %% [markdown]
# Train the model with this new learning rate schedule, and save the history. Remember to rebuild the model to re-initialize all weights and biases. To use the learning rate schedule, add **callbacks=[keras.callbacks.LearningRateScheduler(my_function, verbose=1)]** to model.fit()

# %%
model = Sequential()

model.add(Dense(100, input_dim=X_train_scaled.shape[1], activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(1, activation='linear'))

model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# %%
lr_schedule = keras.callbacks.LearningRateScheduler(time_based_decay, verbose=1)

history_time = model.fit(X_train_scaled,
                                y_train, epochs=100, 
                                batch_size=300, 
                                validation_data=(X_val_scaled, y_val), 
                                callbacks=[lr_schedule]) ## callbacks = time_based_decay
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.001.
# Epoch 1/100
# 13/13 [==============================] - 1s 12ms/step - loss: 0.3222 - val_loss: 0.2222 - lr: 0.0010
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.0009999900000999989.
# Epoch 2/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1716 - val_loss: 0.1157 - lr: 9.9999e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.000999980000399992.
# Epoch 3/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0997 - val_loss: 0.0637 - lr: 9.9998e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.000999970000899973.
# Epoch 4/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0628 - val_loss: 0.0416 - lr: 9.9997e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.000999960001599936.
# Epoch 5/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0495 - val_loss: 0.0340 - lr: 9.9996e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.000999950002499875.
# Epoch 6/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0460 - val_loss: 0.0315 - lr: 9.9995e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.000999940003599784.
# Epoch 7/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0441 - val_loss: 0.0300 - lr: 9.9994e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.000999930004899657.
# Epoch 8/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0428 - val_loss: 0.0308 - lr: 9.9993e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.000999920006399488.
# Epoch 9/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0417 - val_loss: 0.0302 - lr: 9.9992e-04
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.0009999100080992712.
# Epoch 10/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0408 - val_loss: 0.0294 - lr: 9.9991e-04
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.000999900009999.
# Epoch 11/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0401 - val_loss: 0.0281 - lr: 9.9990e-04
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.000999890012098669.
# Epoch 12/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0395 - val_loss: 0.0294 - lr: 9.9989e-04
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.0009998800143982724.
# Epoch 13/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0387 - val_loss: 0.0277 - lr: 9.9988e-04
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.0009998700168978034.
# Epoch 14/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0383 - val_loss: 0.0275 - lr: 9.9987e-04
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.0009998600195972563.
# Epoch 15/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0382 - val_loss: 0.0272 - lr: 9.9986e-04
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.0009998500224966255.
# Epoch 16/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0372 - val_loss: 0.0266 - lr: 9.9985e-04
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.0009998400255959048.
# Epoch 17/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0370 - val_loss: 0.0280 - lr: 9.9984e-04
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.0009998300288950879.
# Epoch 18/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0370 - val_loss: 0.0273 - lr: 9.9983e-04
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.000999820032394169.
# Epoch 19/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0364 - val_loss: 0.0273 - lr: 9.9982e-04
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.0009998100360931424.
# Epoch 20/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0362 - val_loss: 0.0267 - lr: 9.9981e-04
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.0009998000399920016.
# Epoch 21/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0358 - val_loss: 0.0261 - lr: 9.9980e-04
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.000999790044090741.
# Epoch 22/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0348 - val_loss: 0.0260 - lr: 9.9979e-04
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.0009997800483893542.
# Epoch 23/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0346 - val_loss: 0.0263 - lr: 9.9978e-04
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.000999770052887836.
# Epoch 24/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0343 - val_loss: 0.0252 - lr: 9.9977e-04
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.0009997600575861792.
# Epoch 25/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0343 - val_loss: 0.0261 - lr: 9.9976e-04
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.0009997500624843788.
# Epoch 26/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0338 - val_loss: 0.0250 - lr: 9.9975e-04
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.0009997400675824286.
# Epoch 27/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0335 - val_loss: 0.0255 - lr: 9.9974e-04
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.0009997300728803223.
# Epoch 28/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0331 - val_loss: 0.0247 - lr: 9.9973e-04
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.0009997200783780542.
# Epoch 29/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0328 - val_loss: 0.0253 - lr: 9.9972e-04
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.0009997100840756182.
# Epoch 30/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0327 - val_loss: 0.0258 - lr: 9.9971e-04
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.000999700089973008.
# Epoch 31/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0329 - val_loss: 0.0252 - lr: 9.9970e-04
#
# Epoch 32: LearningRateScheduler setting learning rate to 0.0009996900960702183.
# Epoch 32/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0325 - val_loss: 0.0255 - lr: 9.9969e-04
#
# Epoch 33: LearningRateScheduler setting learning rate to 0.0009996801023672425.
# Epoch 33/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0321 - val_loss: 0.0243 - lr: 9.9968e-04
#
# Epoch 34: LearningRateScheduler setting learning rate to 0.000999670108864075.
# Epoch 34/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0315 - val_loss: 0.0249 - lr: 9.9967e-04
#
# Epoch 35: LearningRateScheduler setting learning rate to 0.0009996601155607093.
# Epoch 35/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0318 - val_loss: 0.0253 - lr: 9.9966e-04
#
# Epoch 36: LearningRateScheduler setting learning rate to 0.0009996501224571398.
# Epoch 36/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0313 - val_loss: 0.0250 - lr: 9.9965e-04
#
# Epoch 37: LearningRateScheduler setting learning rate to 0.0009996401295533609.
# Epoch 37/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0310 - val_loss: 0.0245 - lr: 9.9964e-04
#
# Epoch 38: LearningRateScheduler setting learning rate to 0.0009996301368493659.
# Epoch 38/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0310 - val_loss: 0.0247 - lr: 9.9963e-04
#
# Epoch 39: LearningRateScheduler setting learning rate to 0.0009996201443451488.
# Epoch 39/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0315 - val_loss: 0.0238 - lr: 9.9962e-04
#
# Epoch 40: LearningRateScheduler setting learning rate to 0.0009996101520407042.
# Epoch 40/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0307 - val_loss: 0.0246 - lr: 9.9961e-04
#
# Epoch 41: LearningRateScheduler setting learning rate to 0.0009996001599360256.
# Epoch 41/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0304 - val_loss: 0.0245 - lr: 9.9960e-04
#
# Epoch 42: LearningRateScheduler setting learning rate to 0.0009995901680311073.
# Epoch 42/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0301 - val_loss: 0.0241 - lr: 9.9959e-04
#
# Epoch 43: LearningRateScheduler setting learning rate to 0.0009995801763259431.
# Epoch 43/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0303 - val_loss: 0.0252 - lr: 9.9958e-04
#
# Epoch 44: LearningRateScheduler setting learning rate to 0.0009995701848205273.
# Epoch 44/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0311 - val_loss: 0.0262 - lr: 9.9957e-04
#
# Epoch 45: LearningRateScheduler setting learning rate to 0.0009995601935148535.
# Epoch 45/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0304 - val_loss: 0.0235 - lr: 9.9956e-04
#
# Epoch 46: LearningRateScheduler setting learning rate to 0.0009995502024089159.
# Epoch 46/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0299 - val_loss: 0.0238 - lr: 9.9955e-04
#
# Epoch 47: LearningRateScheduler setting learning rate to 0.000999540211502709.
# Epoch 47/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0296 - val_loss: 0.0256 - lr: 9.9954e-04
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.000999530220796226.
# Epoch 48/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0302 - val_loss: 0.0236 - lr: 9.9953e-04
#
# Epoch 49: LearningRateScheduler setting learning rate to 0.000999520230289461.
# Epoch 49/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0296 - val_loss: 0.0234 - lr: 9.9952e-04
#
# Epoch 50: LearningRateScheduler setting learning rate to 0.0009995102399824086.
# Epoch 50/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0296 - val_loss: 0.0258 - lr: 9.9951e-04
#
# Epoch 51: LearningRateScheduler setting learning rate to 0.0009995002498750627.
# Epoch 51/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0301 - val_loss: 0.0251 - lr: 9.9950e-04
#
# Epoch 52: LearningRateScheduler setting learning rate to 0.0009994902599674165.
# Epoch 52/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0292 - val_loss: 0.0239 - lr: 9.9949e-04
#
# Epoch 53: LearningRateScheduler setting learning rate to 0.000999480270259465.
# Epoch 53/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0291 - val_loss: 0.0250 - lr: 9.9948e-04
#
# Epoch 54: LearningRateScheduler setting learning rate to 0.000999470280751202.
# Epoch 54/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0288 - val_loss: 0.0232 - lr: 9.9947e-04
#
# Epoch 55: LearningRateScheduler setting learning rate to 0.000999460291442621.
# Epoch 55/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0290 - val_loss: 0.0238 - lr: 9.9946e-04
#
# Epoch 56: LearningRateScheduler setting learning rate to 0.0009994503023337165.
# Epoch 56/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0287 - val_loss: 0.0234 - lr: 9.9945e-04
#
# Epoch 57: LearningRateScheduler setting learning rate to 0.0009994403134244824.
# Epoch 57/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0292 - val_loss: 0.0248 - lr: 9.9944e-04
#
# Epoch 58: LearningRateScheduler setting learning rate to 0.0009994303247149127.
# Epoch 58/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0286 - val_loss: 0.0234 - lr: 9.9943e-04
#
# Epoch 59: LearningRateScheduler setting learning rate to 0.0009994203362050011.
# Epoch 59/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0286 - val_loss: 0.0236 - lr: 9.9942e-04
#
# Epoch 60: LearningRateScheduler setting learning rate to 0.000999410347894742.
# Epoch 60/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0277 - val_loss: 0.0231 - lr: 9.9941e-04
#
# Epoch 61: LearningRateScheduler setting learning rate to 0.0009994003597841297.
# Epoch 61/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0280 - val_loss: 0.0233 - lr: 9.9940e-04
#
# Epoch 62: LearningRateScheduler setting learning rate to 0.0009993903718731574.
# Epoch 62/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0272 - val_loss: 0.0233 - lr: 9.9939e-04
#
# Epoch 63: LearningRateScheduler setting learning rate to 0.0009993803841618196.
# Epoch 63/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0271 - val_loss: 0.0233 - lr: 9.9938e-04
#
# Epoch 64: LearningRateScheduler setting learning rate to 0.0009993703966501106.
# Epoch 64/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0268 - val_loss: 0.0225 - lr: 9.9937e-04
#
# Epoch 65: LearningRateScheduler setting learning rate to 0.0009993604093380237.
# Epoch 65/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0269 - val_loss: 0.0228 - lr: 9.9936e-04
#
# Epoch 66: LearningRateScheduler setting learning rate to 0.0009993504222255533.
# Epoch 66/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0267 - val_loss: 0.0233 - lr: 9.9935e-04
#
# Epoch 67: LearningRateScheduler setting learning rate to 0.0009993404353126935.
# Epoch 67/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0267 - val_loss: 0.0244 - lr: 9.9934e-04
#
# Epoch 68: LearningRateScheduler setting learning rate to 0.0009993304485994385.
# Epoch 68/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0269 - val_loss: 0.0232 - lr: 9.9933e-04
#
# Epoch 69: LearningRateScheduler setting learning rate to 0.0009993204620857817.
# Epoch 69/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0265 - val_loss: 0.0231 - lr: 9.9932e-04
#
# Epoch 70: LearningRateScheduler setting learning rate to 0.0009993104757717174.
# Epoch 70/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0266 - val_loss: 0.0244 - lr: 9.9931e-04
#
# Epoch 71: LearningRateScheduler setting learning rate to 0.00099930048965724.
# Epoch 71/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0263 - val_loss: 0.0229 - lr: 9.9930e-04
#
# Epoch 72: LearningRateScheduler setting learning rate to 0.0009992905037423429.
# Epoch 72/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0259 - val_loss: 0.0227 - lr: 9.9929e-04
#
# Epoch 73: LearningRateScheduler setting learning rate to 0.0009992805180270205.
# Epoch 73/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0262 - val_loss: 0.0228 - lr: 9.9928e-04
#
# Epoch 74: LearningRateScheduler setting learning rate to 0.0009992705325112669.
# Epoch 74/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0265 - val_loss: 0.0234 - lr: 9.9927e-04
#
# Epoch 75: LearningRateScheduler setting learning rate to 0.0009992605471950758.
# Epoch 75/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0260 - val_loss: 0.0229 - lr: 9.9926e-04
#
# Epoch 76: LearningRateScheduler setting learning rate to 0.0009992505620784412.
# Epoch 76/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0258 - val_loss: 0.0243 - lr: 9.9925e-04
#
# Epoch 77: LearningRateScheduler setting learning rate to 0.0009992405771613573.
# Epoch 77/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0265 - val_loss: 0.0261 - lr: 9.9924e-04
#
# Epoch 78: LearningRateScheduler setting learning rate to 0.0009992305924438184.
# Epoch 78/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0271 - val_loss: 0.0231 - lr: 9.9923e-04
#
# Epoch 79: LearningRateScheduler setting learning rate to 0.0009992206079258179.
# Epoch 79/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0253 - val_loss: 0.0228 - lr: 9.9922e-04
#
# Epoch 80: LearningRateScheduler setting learning rate to 0.0009992106236073502.
# Epoch 80/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0251 - val_loss: 0.0230 - lr: 9.9921e-04
#
# Epoch 81: LearningRateScheduler setting learning rate to 0.0009992006394884093.
# Epoch 81/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0250 - val_loss: 0.0246 - lr: 9.9920e-04
#
# Epoch 82: LearningRateScheduler setting learning rate to 0.0009991906555689891.
# Epoch 82/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0250 - val_loss: 0.0227 - lr: 9.9919e-04
#
# Epoch 83: LearningRateScheduler setting learning rate to 0.0009991806718490836.
# Epoch 83/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0244 - val_loss: 0.0225 - lr: 9.9918e-04
#
# Epoch 84: LearningRateScheduler setting learning rate to 0.0009991706883286872.
# Epoch 84/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0243 - val_loss: 0.0229 - lr: 9.9917e-04
#
# Epoch 85: LearningRateScheduler setting learning rate to 0.0009991607050077935.
# Epoch 85/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0251 - val_loss: 0.0252 - lr: 9.9916e-04
#
# Epoch 86: LearningRateScheduler setting learning rate to 0.0009991507218863967.
# Epoch 86/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0249 - val_loss: 0.0220 - lr: 9.9915e-04
#
# Epoch 87: LearningRateScheduler setting learning rate to 0.0009991407389644904.
# Epoch 87/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0243 - val_loss: 0.0222 - lr: 9.9914e-04
#
# Epoch 88: LearningRateScheduler setting learning rate to 0.0009991307562420696.
# Epoch 88/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0243 - val_loss: 0.0218 - lr: 9.9913e-04
#
# Epoch 89: LearningRateScheduler setting learning rate to 0.0009991207737191272.
# Epoch 89/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0236 - val_loss: 0.0224 - lr: 9.9912e-04
#
# Epoch 90: LearningRateScheduler setting learning rate to 0.0009991107913956579.
# Epoch 90/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0235 - val_loss: 0.0221 - lr: 9.9911e-04
#
# Epoch 91: LearningRateScheduler setting learning rate to 0.0009991008092716557.
# Epoch 91/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0236 - val_loss: 0.0225 - lr: 9.9910e-04
#
# Epoch 92: LearningRateScheduler setting learning rate to 0.0009990908273471142.
# Epoch 92/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0232 - val_loss: 0.0223 - lr: 9.9909e-04
#
# Epoch 93: LearningRateScheduler setting learning rate to 0.0009990808456220278.
# Epoch 93/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0233 - val_loss: 0.0228 - lr: 9.9908e-04
#
# Epoch 94: LearningRateScheduler setting learning rate to 0.0009990708640963903.
# Epoch 94/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0237 - val_loss: 0.0241 - lr: 9.9907e-04
#
# Epoch 95: LearningRateScheduler setting learning rate to 0.000999060882770196.
# Epoch 95/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0239 - val_loss: 0.0225 - lr: 9.9906e-04
#
# Epoch 96: LearningRateScheduler setting learning rate to 0.0009990509016434388.
# Epoch 96/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0233 - val_loss: 0.0236 - lr: 9.9905e-04
#
# Epoch 97: LearningRateScheduler setting learning rate to 0.0009990409207161124.
# Epoch 97/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0233 - val_loss: 0.0221 - lr: 9.9904e-04
#
# Epoch 98: LearningRateScheduler setting learning rate to 0.0009990309399882115.
# Epoch 98/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0225 - val_loss: 0.0214 - lr: 9.9903e-04
#
# Epoch 99: LearningRateScheduler setting learning rate to 0.0009990209594597295.
# Epoch 99/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0224 - val_loss: 0.0223 - lr: 9.9902e-04
#
# Epoch 100: LearningRateScheduler setting learning rate to 0.0009990109791306607.
# Epoch 100/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0223 - val_loss: 0.0223 - lr: 9.9901e-04

# %% [markdown]
# ## Step 2: Exponential decay
#
# Repeat Part 3 Step 1 for a different learning schedule that uses exponential decay,
#
# $$ \eta(t)=\eta_0⋅e^{−k⋅t},$$
#
# where $k$ is the decay rate. We can try k=0.01.

# %%
def exponential_decay(epoch, lr):
    initial_lr = 0.001
    k = 0.01
    new_lr = initial_lr * np.exp(-k * epoch)
    return new_lr

# %%
epochs = np.arange(100)
lr = 0.001

learning_rates = [exponential_decay(epoch, lr) for epoch in epochs]

# %%
plt.plot(epochs, learning_rates)
plt.xlabel('Epoch')
plt.ylabel('Learning Rate')
plt.title('Exponential Decay Learning Rate Schedule')
plt.show()

# %%
model = Sequential()

model.add(Dense(100, input_dim=X_train_scaled.shape[1], activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(1, activation='linear'))

model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# %%
lr_schedule = keras.callbacks.LearningRateScheduler(exponential_decay, verbose=1)

history_exp = model.fit(X_train_scaled,
                                y_train, epochs=100, 
                                batch_size=300, 
                                validation_data=(X_val_scaled, y_val), 
                                callbacks=[lr_schedule])
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.001.
# Epoch 1/100
# 13/13 [==============================] - 1s 12ms/step - loss: 0.3853 - val_loss: 0.2424 - lr: 0.0010
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.000990049833749168.
# Epoch 2/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1858 - val_loss: 0.1206 - lr: 9.9005e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.0009801986733067552.
# Epoch 3/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0992 - val_loss: 0.0667 - lr: 9.8020e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.0009704455335485082.
# Epoch 4/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0623 - val_loss: 0.0470 - lr: 9.7045e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0009607894391523232.
# Epoch 5/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0508 - val_loss: 0.0361 - lr: 9.6079e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.000951229424500714.
# Epoch 6/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0457 - val_loss: 0.0325 - lr: 9.5123e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.0009417645335842487.
# Epoch 7/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0439 - val_loss: 0.0314 - lr: 9.4176e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0009323938199059483.
# Epoch 8/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0430 - val_loss: 0.0305 - lr: 9.3239e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.0009231163463866358.
# Epoch 9/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0427 - val_loss: 0.0295 - lr: 9.2312e-04
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.0009139311852712283.
# Epoch 10/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0414 - val_loss: 0.0291 - lr: 9.1393e-04
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.0009048374180359595.
# Epoch 11/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0409 - val_loss: 0.0292 - lr: 9.0484e-04
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.0008958341352965282.
# Epoch 12/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0401 - val_loss: 0.0296 - lr: 8.9583e-04
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.0008869204367171575.
# Epoch 13/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0399 - val_loss: 0.0293 - lr: 8.8692e-04
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.0008780954309205613.
# Epoch 14/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0392 - val_loss: 0.0286 - lr: 8.7810e-04
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.0008693582353988059.
# Epoch 15/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0387 - val_loss: 0.0278 - lr: 8.6936e-04
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.0008607079764250578.
# Epoch 16/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0382 - val_loss: 0.0281 - lr: 8.6071e-04
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.0008521437889662113.
# Epoch 17/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0378 - val_loss: 0.0274 - lr: 8.5214e-04
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.0008436648165963838.
# Epoch 18/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0379 - val_loss: 0.0271 - lr: 8.4366e-04
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.000835270211411272.
# Epoch 19/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0371 - val_loss: 0.0271 - lr: 8.3527e-04
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.0008269591339433623.
# Epoch 20/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0370 - val_loss: 0.0277 - lr: 8.2696e-04
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.0008187307530779819.
# Epoch 21/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0369 - val_loss: 0.0267 - lr: 8.1873e-04
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.0008105842459701871.
# Epoch 22/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0363 - val_loss: 0.0264 - lr: 8.1058e-04
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.0008025187979624785.
# Epoch 23/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0360 - val_loss: 0.0271 - lr: 8.0252e-04
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.000794533602503334.
# Epoch 24/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0357 - val_loss: 0.0265 - lr: 7.9453e-04
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.0007866278610665535.
# Epoch 25/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0356 - val_loss: 0.0264 - lr: 7.8663e-04
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.0007788007830714049.
# Epoch 26/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0352 - val_loss: 0.0263 - lr: 7.7880e-04
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.0007710515858035663.
# Epoch 27/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0349 - val_loss: 0.0259 - lr: 7.7105e-04
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.0007633794943368531.
# Epoch 28/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0347 - val_loss: 0.0260 - lr: 7.6338e-04
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.0007557837414557255.
# Epoch 29/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0345 - val_loss: 0.0260 - lr: 7.5578e-04
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.0007482635675785653.
# Epoch 30/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0339 - val_loss: 0.0254 - lr: 7.4826e-04
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.0007408182206817179.
# Epoch 31/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0337 - val_loss: 0.0260 - lr: 7.4082e-04
#
# Epoch 32: LearningRateScheduler setting learning rate to 0.0007334469562242892.
# Epoch 32/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0336 - val_loss: 0.0259 - lr: 7.3345e-04
#
# Epoch 33: LearningRateScheduler setting learning rate to 0.000726149037073691.
# Epoch 33/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0332 - val_loss: 0.0260 - lr: 7.2615e-04
#
# Epoch 34: LearningRateScheduler setting learning rate to 0.0007189237334319262.
# Epoch 34/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0330 - val_loss: 0.0252 - lr: 7.1892e-04
#
# Epoch 35: LearningRateScheduler setting learning rate to 0.0007117703227626096.
# Epoch 35/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0327 - val_loss: 0.0253 - lr: 7.1177e-04
#
# Epoch 36: LearningRateScheduler setting learning rate to 0.0007046880897187134.
# Epoch 36/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0326 - val_loss: 0.0263 - lr: 7.0469e-04
#
# Epoch 37: LearningRateScheduler setting learning rate to 0.000697676326071031.
# Epoch 37/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0331 - val_loss: 0.0275 - lr: 6.9768e-04
#
# Epoch 38: LearningRateScheduler setting learning rate to 0.0006907343306373547.
# Epoch 38/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0329 - val_loss: 0.0263 - lr: 6.9073e-04
#
# Epoch 39: LearningRateScheduler setting learning rate to 0.0006838614092123559.
# Epoch 39/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0321 - val_loss: 0.0249 - lr: 6.8386e-04
#
# Epoch 40: LearningRateScheduler setting learning rate to 0.0006770568744981646.
# Epoch 40/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0319 - val_loss: 0.0250 - lr: 6.7706e-04
#
# Epoch 41: LearningRateScheduler setting learning rate to 0.0006703200460356394.
# Epoch 41/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0314 - val_loss: 0.0247 - lr: 6.7032e-04
#
# Epoch 42: LearningRateScheduler setting learning rate to 0.0006636502501363194.
# Epoch 42/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0313 - val_loss: 0.0248 - lr: 6.6365e-04
#
# Epoch 43: LearningRateScheduler setting learning rate to 0.0006570468198150568.
# Epoch 43/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0312 - val_loss: 0.0250 - lr: 6.5705e-04
#
# Epoch 44: LearningRateScheduler setting learning rate to 0.0006505090947233165.
# Epoch 44/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0313 - val_loss: 0.0243 - lr: 6.5051e-04
#
# Epoch 45: LearningRateScheduler setting learning rate to 0.0006440364210831414.
# Epoch 45/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0311 - val_loss: 0.0245 - lr: 6.4404e-04
#
# Epoch 46: LearningRateScheduler setting learning rate to 0.0006376281516217733.
# Epoch 46/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0311 - val_loss: 0.0252 - lr: 6.3763e-04
#
# Epoch 47: LearningRateScheduler setting learning rate to 0.000631283645506926.
# Epoch 47/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0309 - val_loss: 0.0244 - lr: 6.3128e-04
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.0006250022682827008.
# Epoch 48/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0306 - val_loss: 0.0244 - lr: 6.2500e-04
#
# Epoch 49: LearningRateScheduler setting learning rate to 0.0006187833918061408.
# Epoch 49/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0302 - val_loss: 0.0245 - lr: 6.1878e-04
#
# Epoch 50: LearningRateScheduler setting learning rate to 0.0006126263941844161.
# Epoch 50/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0301 - val_loss: 0.0245 - lr: 6.1263e-04
#
# Epoch 51: LearningRateScheduler setting learning rate to 0.0006065306597126335.
# Epoch 51/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0299 - val_loss: 0.0243 - lr: 6.0653e-04
#
# Epoch 52: LearningRateScheduler setting learning rate to 0.000600495578812266.
# Epoch 52/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0300 - val_loss: 0.0243 - lr: 6.0050e-04
#
# Epoch 53: LearningRateScheduler setting learning rate to 0.0005945205479701944.
# Epoch 53/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0297 - val_loss: 0.0240 - lr: 5.9452e-04
#
# Epoch 54: LearningRateScheduler setting learning rate to 0.0005886049696783552.
# Epoch 54/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0297 - val_loss: 0.0246 - lr: 5.8860e-04
#
# Epoch 55: LearningRateScheduler setting learning rate to 0.0005827482523739897.
# Epoch 55/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0298 - val_loss: 0.0246 - lr: 5.8275e-04
#
# Epoch 56: LearningRateScheduler setting learning rate to 0.0005769498103804867.
# Epoch 56/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0298 - val_loss: 0.0243 - lr: 5.7695e-04
#
# Epoch 57: LearningRateScheduler setting learning rate to 0.0005712090638488148.
# Epoch 57/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0292 - val_loss: 0.0243 - lr: 5.7121e-04
#
# Epoch 58: LearningRateScheduler setting learning rate to 0.0005655254386995371.
# Epoch 58/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0292 - val_loss: 0.0249 - lr: 5.6553e-04
#
# Epoch 59: LearningRateScheduler setting learning rate to 0.000559898366565402.
# Epoch 59/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0291 - val_loss: 0.0253 - lr: 5.5990e-04
#
# Epoch 60: LearningRateScheduler setting learning rate to 0.0005543272847345071.
# Epoch 60/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0290 - val_loss: 0.0240 - lr: 5.5433e-04
#
# Epoch 61: LearningRateScheduler setting learning rate to 0.0005488116360940265.
# Epoch 61/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0285 - val_loss: 0.0239 - lr: 5.4881e-04
#
# Epoch 62: LearningRateScheduler setting learning rate to 0.0005433508690744998.
# Epoch 62/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0285 - val_loss: 0.0240 - lr: 5.4335e-04
#
# Epoch 63: LearningRateScheduler setting learning rate to 0.0005379444375946745.
# Epoch 63/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0285 - val_loss: 0.0236 - lr: 5.3794e-04
#
# Epoch 64: LearningRateScheduler setting learning rate to 0.0005325918010068972.
# Epoch 64/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0281 - val_loss: 0.0239 - lr: 5.3259e-04
#
# Epoch 65: LearningRateScheduler setting learning rate to 0.0005272924240430486.
# Epoch 65/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0282 - val_loss: 0.0243 - lr: 5.2729e-04
#
# Epoch 66: LearningRateScheduler setting learning rate to 0.000522045776761016.
# Epoch 66/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0281 - val_loss: 0.0253 - lr: 5.2205e-04
#
# Epoch 67: LearningRateScheduler setting learning rate to 0.0005168513344916992.
# Epoch 67/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0286 - val_loss: 0.0241 - lr: 5.1685e-04
#
# Epoch 68: LearningRateScheduler setting learning rate to 0.0005117085777865425.
# Epoch 68/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0281 - val_loss: 0.0235 - lr: 5.1171e-04
#
# Epoch 69: LearningRateScheduler setting learning rate to 0.0005066169923655895.
# Epoch 69/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0280 - val_loss: 0.0235 - lr: 5.0662e-04
#
# Epoch 70: LearningRateScheduler setting learning rate to 0.0005015760690660555.
# Epoch 70/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0276 - val_loss: 0.0233 - lr: 5.0158e-04
#
# Epoch 71: LearningRateScheduler setting learning rate to 0.0004965853037914095.
# Epoch 71/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0276 - val_loss: 0.0237 - lr: 4.9659e-04
#
# Epoch 72: LearningRateScheduler setting learning rate to 0.0004916441974609651.
# Epoch 72/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0276 - val_loss: 0.0238 - lr: 4.9164e-04
#
# Epoch 73: LearningRateScheduler setting learning rate to 0.0004867522559599717.
# Epoch 73/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0274 - val_loss: 0.0243 - lr: 4.8675e-04
#
# Epoch 74: LearningRateScheduler setting learning rate to 0.00048190899009020245.
# Epoch 74/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0272 - val_loss: 0.0240 - lr: 4.8191e-04
#
# Epoch 75: LearningRateScheduler setting learning rate to 0.0004771139155210344.
# Epoch 75/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0271 - val_loss: 0.0241 - lr: 4.7711e-04
#
# Epoch 76: LearningRateScheduler setting learning rate to 0.0004723665527410147.
# Epoch 76/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0271 - val_loss: 0.0238 - lr: 4.7237e-04
#
# Epoch 77: LearningRateScheduler setting learning rate to 0.00046766642700990925.
# Epoch 77/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0270 - val_loss: 0.0232 - lr: 4.6767e-04
#
# Epoch 78: LearningRateScheduler setting learning rate to 0.00046301306831122806.
# Epoch 78/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0268 - val_loss: 0.0238 - lr: 4.6301e-04
#
# Epoch 79: LearningRateScheduler setting learning rate to 0.00045840601130522354.
# Epoch 79/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0268 - val_loss: 0.0236 - lr: 4.5841e-04
#
# Epoch 80: LearningRateScheduler setting learning rate to 0.0004538447952823558.
# Epoch 80/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0269 - val_loss: 0.0233 - lr: 4.5384e-04
#
# Epoch 81: LearningRateScheduler setting learning rate to 0.0004493289641172216.
# Epoch 81/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0272 - val_loss: 0.0233 - lr: 4.4933e-04
#
# Epoch 82: LearningRateScheduler setting learning rate to 0.0004448580662229411.
# Epoch 82/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0266 - val_loss: 0.0233 - lr: 4.4486e-04
#
# Epoch 83: LearningRateScheduler setting learning rate to 0.0004404316545059993.
# Epoch 83/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0264 - val_loss: 0.0232 - lr: 4.4043e-04
#
# Epoch 84: LearningRateScheduler setting learning rate to 0.0004360492863215356.
# Epoch 84/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0265 - val_loss: 0.0242 - lr: 4.3605e-04
#
# Epoch 85: LearningRateScheduler setting learning rate to 0.00043171052342907973.
# Epoch 85/100
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0265 - val_loss: 0.0231 - lr: 4.3171e-04
#
# Epoch 86: LearningRateScheduler setting learning rate to 0.0004274149319487267.
# Epoch 86/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0264 - val_loss: 0.0236 - lr: 4.2741e-04
#
# Epoch 87: LearningRateScheduler setting learning rate to 0.00042316208231774885.
# Epoch 87/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0262 - val_loss: 0.0238 - lr: 4.2316e-04
#
# Epoch 88: LearningRateScheduler setting learning rate to 0.000418951549247639.
# Epoch 88/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0263 - val_loss: 0.0230 - lr: 4.1895e-04
#
# Epoch 89: LearningRateScheduler setting learning rate to 0.0004147829116815814.
# Epoch 89/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0261 - val_loss: 0.0237 - lr: 4.1478e-04
#
# Epoch 90: LearningRateScheduler setting learning rate to 0.0004106557527523455.
# Epoch 90/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0257 - val_loss: 0.0235 - lr: 4.1066e-04
#
# Epoch 91: LearningRateScheduler setting learning rate to 0.00040656965974059914.
# Epoch 91/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0259 - val_loss: 0.0236 - lr: 4.0657e-04
#
# Epoch 92: LearningRateScheduler setting learning rate to 0.00040252422403363596.
# Epoch 92/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0259 - val_loss: 0.0230 - lr: 4.0252e-04
#
# Epoch 93: LearningRateScheduler setting learning rate to 0.00039851904108451417.
# Epoch 93/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0257 - val_loss: 0.0232 - lr: 3.9852e-04
#
# Epoch 94: LearningRateScheduler setting learning rate to 0.0003945537103716011.
# Epoch 94/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0256 - val_loss: 0.0231 - lr: 3.9455e-04
#
# Epoch 95: LearningRateScheduler setting learning rate to 0.00039062783535852107.
# Epoch 95/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0253 - val_loss: 0.0236 - lr: 3.9063e-04
#
# Epoch 96: LearningRateScheduler setting learning rate to 0.00038674102345450116.
# Epoch 96/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0254 - val_loss: 0.0242 - lr: 3.8674e-04
#
# Epoch 97: LearningRateScheduler setting learning rate to 0.0003828928859751121.
# Epoch 97/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0255 - val_loss: 0.0239 - lr: 3.8289e-04
#
# Epoch 98: LearningRateScheduler setting learning rate to 0.00037908303810339886.
# Epoch 98/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0252 - val_loss: 0.0232 - lr: 3.7908e-04
#
# Epoch 99: LearningRateScheduler setting learning rate to 0.0003753110988513996.
# Epoch 99/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0252 - val_loss: 0.0232 - lr: 3.7531e-04
#
# Epoch 100: LearningRateScheduler setting learning rate to 0.0003715766910220457.
# Epoch 100/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0251 - val_loss: 0.0230 - lr: 3.7158e-04

# %% [markdown]
# ## Step 3:
#
# Graph the loss for the three learning schedules we have (constant, time decay, exponential decay). Zoom in on the values at the end of the training to better see the differences.

# %%
#constant
plt.plot(history.history['loss'], label='Constant LR Training', color='blue')
plt.plot(history.history['val_loss'], label='Constant LR Validation', linestyle='--', color='blue')

#time based
plt.plot(history_time.history['loss'], label='Time Decay LR Training', color='green')
plt.plot(history_time.history['val_loss'], label='Time Decay LR Validation', linestyle='--', color='green')

#exp decay
plt.plot(history_exp.history['loss'], label='Exponential Decay LR Training', color='red')
plt.plot(history_exp.history['val_loss'], label='Exponential Decay LR Validation', linestyle='--', color='red')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Comparison for Different Learning Rate Schedules')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Part 4: A first convolutional neural network
#
# In the following, we try to improve on our dense NN for the MNIST image dataset with a deep convolutional network. There are two new kinds of layers that will be used, **Conv2D** and **MaxPool2D**. We will discuss this in detail next week, but for now just look at the code. While the code runs, try to figure out the structure of the network. You might want to look up these layers in the keras documentation.

# %%
(x_train, y_train),(x_test, y_test) = keras.datasets.mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0  

x_train = x_train.reshape(-1,28,28,1)
x_test = x_test.reshape(-1,28,28,1)

x_train, x_val, y_train, y_val = train_test_split(
	x_train, y_train, test_size = 1/6, random_state=42)

print('x_train.shape =', x_train.shape)
print('y_train.shape =', y_train.shape)
print('x_val.shape =', x_val.shape)
print('y_val.shape =', y_val.shape)
print('x_test.shape =', x_test.shape)
print('y_test.shape =', y_test.shape)

# %%
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D

def make_conv_model():
  model = Sequential()

  model.add(Conv2D(filters = 10, kernel_size = (5,5),padding = 'Same', 
                  activation ='relu', input_shape = (28,28,1)))
  model.add(Conv2D(filters = 10, kernel_size = (5,5),padding = 'Same', 
                  activation ='relu'))
  model.add(MaxPool2D(pool_size=(2,2)))
  model.add(Flatten())
  model.add(Dense(64, activation = "relu"))
  model.add(Dropout(0.2))
  model.add(Dense(10, activation = "softmax"))
  optimizer = keras.optimizers.Adam()

  model.compile(optimizer=optimizer,
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy']) 
  return model

def make_dense_model():
  model = Sequential()
  model.add(Flatten(input_shape = (28,28,1)))
  model.add(Dense(512, activation = "relu"))
  model.add(Dropout(0.2))
  model.add(Dense(256, activation = "relu"))
  model.add(Dropout(0.2))
  model.add(Dense(10, activation = "softmax"))
  optimizer = keras.optimizers.Adam()

  model.compile(optimizer=optimizer,
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy']) 
  return model

simple_conv_model = make_conv_model()
dense_model = make_dense_model()
simple_conv_model.summary()
dense_model.summary()

# %%
epochs = 40
batch_size = 86

simple_conv_history = simple_conv_model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_val, y_val), verbose=1)
dense_history = dense_model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_val, y_val),verbose=1)

# %%
simple_conv_test_loss, simple_conv_test_acc = simple_conv_model.evaluate(x_test, y_test)
dense_test_loss, dense_test_acc = dense_model.evaluate(x_test, y_test)

plt.plot(dense_history.history["accuracy"], "b--",label="dense training accuracy")
plt.plot(dense_history.history["val_accuracy"], "b-",label="dense val accuracy")
plt.axhline(dense_test_acc, color="k", linestyle=":", label="dense test accuracy")
plt.plot(simple_conv_history.history["accuracy"], "g--",label="simple conv training accuracy")
plt.plot(simple_conv_history.history["val_accuracy"], "g-",label="simple conv val accuracy")
plt.axhline(simple_conv_test_acc,color="k", linestyle="--", label="simple conv test accuracy")
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0.94, 1.005)
plt.legend()
