# %% [markdown]
# Group 5: Sam Young, Raveel Tejani

# %% [markdown]
# # Lab Notebook 20
#
# In this notebook, we use a fully connected neural network to solve a previously seen problem in regression: the photometric redshift problem  We also explore the effect of loss function and learning rate schedule.
#
# *Modified from: Copyright: Viviana Acquaviva (2023). License: [BSD-3-clause](https://opensource.org/license/bsd-3-clause/)*

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
import keras

from keras.models import Sequential #the model is built adding layers one after the other
from keras.layers import Dense #fully connected layers: every output talks to every input
from keras.layers import Dropout #for regularization
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# 2024-03-20 15:43:47.570535: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Part 1: PhotoZ regression with a deep NN

# %% [markdown]
# ## Step 1

# %% [markdown]
# Let us begin with the reduced (high-quality) data set we used for Bagging and Boosting methods. For reference, our best model achieved an outlier fraction of 4%.
#
# Read in 'sel_features.csv' and 'sel_target.csv' as X and y, respectively. You will need to shuffle X and y (use random_state=12) as we did in the previous notebook.

# %%
X = pd.read_csv('sel_features.csv', delimiter =  "	")
y = pd.read_csv('sel_target.csv')

X.shape, y.shape
# Out:
# ((6307, 6), (6307, 1))

# %% [markdown]
# Divide the data into fifths; we would like to use a 60/20/20 split for training/validation/test. Define these arrays.

# %%
X, y = shuffle(X, y, random_state = 12)

X_train = X[0:3785]
X_val   = X[3785: 3785 + 1261]
X_test  = X[3785 + 1261: 3785 + (2*1261)]

y_train = y[0:3785]
y_val   = y[3785: 3785 + 1261]
y_test  = y[3785 + 1261: 3785 + (2*1261)]

print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)

X.tail() == X_test.tail()
# Out:
# (3785, 6)
# (3785, 1)
# (1261, 6)
# (1261, 1)
# (1261, 6)
# (1261, 1)
#       u_apercor  g_apercor  r_apercor  i_apercor  z_apercor  y_apercor
# 3714       True       True       True       True       True       True
# 3325       True       True       True       True       True       True
# 1414       True       True       True       True       True       True
# 5787       True       True       True       True       True       True
# 5963       True       True       True       True       True       True

# %% [markdown]
# We know that we need to scale our data! Do so below:

# %%
scaler = StandardScaler()

Xs_train = scaler.fit_transform(X_train)
Xs_val = scaler.transform(X_val)
Xs_val = scaler.transform(X_val)
Xs_test = scaler.transform(X_test)

# %% [markdown]
# ## Step 2
#
# In a regression problem, we will choose a different activation for the output layer (linear), and an appropriate loss function (MSE). Our input layer has **six neurons** for this problem. For other parameters and the network structure, we can start with two relu-activated layers with **100 neurons** and go from there.
#
# 1. Define your model using "Sequential()".
# 2. Define your optimizer using the Adam optimizer from keras, and use the default learning rate of 0.001.
# 3. Add an input layer and specify a size of 100 neurons (size=number of original features).
# 4. Add one hidden layer and specify 100 neurons.
# 5. Add an output layer with one neuron
# 6. Finally, compile your model using MSE as the loss.

# %%
from keras.optimizers import Adam

# %%
model = keras.Sequential([
    keras.layers.Dense(100, activation='relu', input_shape=(6,)),
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(1, activation='linear')
])

model.compile(optimizer=Adam(learning_rate=0.001), loss='MeanSquaredError')

# %% [markdown]
# To create your neural network, fit your model and use 100 epochs and batch size = 300:

# %%
history = model.fit(Xs_train, y_train,
                    epochs = 100,
                    batch_size = 300,
                    validation_data = (Xs_val, y_val))
# Out:
# Epoch 1/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.2750 - val_loss: 0.1636
# Epoch 2/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1242 - val_loss: 0.0850
# Epoch 3/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0734 - val_loss: 0.0502
# Epoch 4/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0535 - val_loss: 0.0362
# Epoch 5/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0475 - val_loss: 0.0331
# Epoch 6/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0449 - val_loss: 0.0313
# Epoch 7/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0428 - val_loss: 0.0320
# Epoch 8/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0412 - val_loss: 0.0313
# Epoch 9/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0402 - val_loss: 0.0305
# Epoch 10/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0396 - val_loss: 0.0304
# Epoch 11/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0285
# Epoch 12/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0377 - val_loss: 0.0285
# Epoch 13/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0372 - val_loss: 0.0285
# Epoch 14/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0370 - val_loss: 0.0275
# Epoch 15/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0364 - val_loss: 0.0279
# Epoch 16/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0360 - val_loss: 0.0272
# Epoch 17/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0356 - val_loss: 0.0269
# Epoch 18/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0350 - val_loss: 0.0278
# Epoch 19/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0352 - val_loss: 0.0270
# Epoch 20/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0347 - val_loss: 0.0261
# Epoch 21/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0339 - val_loss: 0.0258
# Epoch 22/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0336 - val_loss: 0.0258
# Epoch 23/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0337 - val_loss: 0.0268
# Epoch 24/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0333 - val_loss: 0.0254
# Epoch 25/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0327 - val_loss: 0.0251
# Epoch 26/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0325 - val_loss: 0.0259
# Epoch 27/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0325 - val_loss: 0.0255
# Epoch 28/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0325 - val_loss: 0.0257
# Epoch 29/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0330 - val_loss: 0.0249
# Epoch 30/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0320 - val_loss: 0.0261
# Epoch 31/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0319 - val_loss: 0.0257
# Epoch 32/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0311 - val_loss: 0.0241
# Epoch 33/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0306 - val_loss: 0.0262
# Epoch 34/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0308 - val_loss: 0.0244
# Epoch 35/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0307 - val_loss: 0.0243
# Epoch 36/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0306 - val_loss: 0.0239
# Epoch 37/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0298 - val_loss: 0.0240
# Epoch 38/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0296 - val_loss: 0.0241
# Epoch 39/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0293 - val_loss: 0.0240
# Epoch 40/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0291 - val_loss: 0.0256
# Epoch 41/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0293 - val_loss: 0.0236
# Epoch 42/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0291 - val_loss: 0.0248
# Epoch 43/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0295 - val_loss: 0.0261
# Epoch 44/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0288 - val_loss: 0.0240
# Epoch 45/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0283 - val_loss: 0.0233
# Epoch 46/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0281 - val_loss: 0.0238
# Epoch 47/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0278 - val_loss: 0.0230
# Epoch 48/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0279 - val_loss: 0.0232
# Epoch 49/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0280 - val_loss: 0.0234
# Epoch 50/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0287 - val_loss: 0.0246
# Epoch 51/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0290 - val_loss: 0.0237
# Epoch 52/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0270 - val_loss: 0.0233
# Epoch 53/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0271 - val_loss: 0.0235
# Epoch 54/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0266 - val_loss: 0.0235
# Epoch 55/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0266 - val_loss: 0.0229
# Epoch 56/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0266 - val_loss: 0.0234
# Epoch 57/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0262 - val_loss: 0.0249
# Epoch 58/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0273 - val_loss: 0.0234
# Epoch 59/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0265 - val_loss: 0.0230
# Epoch 60/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0266 - val_loss: 0.0248
# Epoch 61/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0267 - val_loss: 0.0240
# Epoch 62/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0263 - val_loss: 0.0238
# Epoch 63/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0276 - val_loss: 0.0241
# Epoch 64/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0271 - val_loss: 0.0237
# Epoch 65/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0264 - val_loss: 0.0240
# Epoch 66/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0254 - val_loss: 0.0232
# Epoch 67/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0249 - val_loss: 0.0231
# Epoch 68/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0251 - val_loss: 0.0223
# Epoch 69/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0249 - val_loss: 0.0233
# Epoch 70/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0252 - val_loss: 0.0231
# Epoch 71/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0250 - val_loss: 0.0228
# Epoch 72/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0251 - val_loss: 0.0230
# Epoch 73/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0240 - val_loss: 0.0222
# Epoch 74/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0238 - val_loss: 0.0226
# Epoch 75/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0239 - val_loss: 0.0223
# Epoch 76/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0238 - val_loss: 0.0220
# Epoch 77/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0239 - val_loss: 0.0222
# Epoch 78/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0241 - val_loss: 0.0229
# Epoch 79/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0237 - val_loss: 0.0239
# Epoch 80/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0236 - val_loss: 0.0231
# Epoch 81/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0236 - val_loss: 0.0221
# Epoch 82/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0230 - val_loss: 0.0225
# Epoch 83/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0231 - val_loss: 0.0235
# Epoch 84/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0226 - val_loss: 0.0223
# Epoch 85/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0227 - val_loss: 0.0236
# Epoch 86/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0232 - val_loss: 0.0221
# Epoch 87/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0223 - val_loss: 0.0220
# Epoch 88/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0222 - val_loss: 0.0229
# Epoch 89/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0236 - val_loss: 0.0224
# Epoch 90/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0226 - val_loss: 0.0224
# Epoch 91/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0221 - val_loss: 0.0216
# Epoch 92/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0217 - val_loss: 0.0222
# Epoch 93/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0219 - val_loss: 0.0228
# Epoch 94/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0228 - val_loss: 0.0235
# Epoch 95/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0217 - val_loss: 0.0225
# Epoch 96/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0226 - val_loss: 0.0218
# Epoch 97/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0218 - val_loss: 0.0231
# Epoch 98/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0216 - val_loss: 0.0221
# Epoch 99/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0210 - val_loss: 0.0211
# Epoch 100/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0212 - val_loss: 0.0220

# %% [markdown]
# Use "model.evaluate" to find the MSE:

# %%
scores = model.evaluate(Xs_test, y_test, verbose=1)
print("MSE: {}".format(scores))
# Out:
# 40/40 [==============================] - 0s 522us/step - loss: 0.0281
# MSE: 0.028119917958974838

# %% [markdown]
# ## Step 3
#
# As in the previous lab, we can plot the loss as a function of epoch from the train and validation data sets. Here the loss is of course the MSE.

# %%
plt.plot(history.history['loss'], label='train set')
plt.plot(history.history['val_loss'], label='validation set')
plt.xlabel('epoch')
plt.ylabel('mean squared error')
plt.legend()
plt.show()

# %% [markdown]
# As always with regression problems, it is helpful to plot the predictions against the true values. Plot estimated redshift versus true redshift in a scatter plot below:

# %%
y_pred = model.predict(Xs_test)

plt.scatter(y_test, y_pred, color='black', alpha=0.25, marker = 'o')
plt.xlabel('true redshift')
plt.ylabel('estimated redshift')
plt.show()
# Out:
# 40/40 [==============================] - 0s 439us/step

# %% [markdown]
# ## Step 4
#
# We didn't do cross validation, so we can only generate predictions on our single test fold in order to derive the other metrics we are interested in.
#
# First, calculate the Outlier Fraction (OLF):
#
# $\mathrm{OLF} = \mathrm{num}\left ( \frac{|\Delta z|}{1+z_{\mathrm{true}}} > 0.15 = \mathrm{true} \right)/N$
#
# *The numerator is the number of instances where $\frac{|\Delta z|}{1+z_{\mathrm{true}}}>0.15$ is true. $N$ is the length of $y_{\mathrm{test}}$.*
#
# We can also calculate the Normalized Median Absolute Deviation (NMAD):
#
# $\sigma_{\mathrm{NMAD}}=1.48 \times \mathrm{median}\left ( \frac{|\Delta z|}{1+z_{\mathrm{true}}}\right )$

# %%
outlier_frac = len(y_test.to_numpy()[(np.abs(y_test - y_pred)/(1 + y_test) > 0.15).to_numpy()])/len(y_test)
print('')
print('outlier fraction MSE: {:.4f}'.format(outlier_frac))
# Out:
# outlier fraction MSE: 0.0492

# %%
nmad = np.median(np.abs(y_test - y_pred) /( 1 + y_test)) * 1.48
print('nmad MSE: {:.4f}'.format(nmad))
# Out:
# nmad MSE: 0.0365

# %% [markdown]
# # Part 2: Effect of loss function
#
# So far, we have used the MSE loss in our training, but this choice is not unique. Would using the MAE or MAPE loss functions give better results for the OLF and NMAD parameters?
#
# **Both MAE and MAPE give better results, with MAPE being the best result as it has the smallest nmad**

# %%
model.compile(optimizer=Adam(learning_rate=0.001), loss='MeanAbsoluteError')

history = model.fit(Xs_train, y_train,
                    epochs = 100,
                    batch_size = 300,
                    validation_data = (Xs_val, y_val), verbose = None)

scores = model.evaluate(Xs_test, y_test, verbose=1)
print("MAE: {}".format(scores))

y_pred = model.predict(Xs_test)
outlier_frac = len(y_test.to_numpy()[(np.abs(y_test - y_pred)/(1 + y_test) > 0.15).to_numpy()])/len(y_test)
print('')
print('outlier fraction MAE: {:.4f}'.format(outlier_frac))

nmad = np.median(np.abs(y_test - y_pred) /( 1 + y_test)) * 1.48
print('nmad MAE: {:.4f}'.format(nmad))
# Out:
# 40/40 [==============================] - 0s 485us/step - loss: 0.0594
# MAE: 0.059447526931762695
# 40/40 [==============================] - 0s 427us/step
#
# outlier fraction MAE: 0.0293
# nmad MAE: 0.0256

# %%
model.compile(optimizer=Adam(learning_rate=0.001), loss='MeanAbsolutePercentageError')

history = model.fit(Xs_train, y_train,
                    epochs = 100,
                    batch_size = 300,
                    validation_data = (Xs_val, y_val), verbose = None)

scores = model.evaluate(Xs_test, y_test, verbose=1)
print("MAPE: {}".format(scores))

y_pred = model.predict(Xs_test)
outlier_frac = len(y_test.to_numpy()[(np.abs(y_test - y_pred)/(1 + y_test) > 0.15).to_numpy()])/len(y_test)
print('')
print('outlier fraction MAPE: {:.4f}'.format(outlier_frac))

nmad = np.median(np.abs(y_test - y_pred) /( 1 + y_test)) * 1.48
print('nmad MAPE: {:.4f}'.format(nmad))
# Out:
# 40/40 [==============================] - 0s 450us/step - loss: 9.2954
# MAPE: 9.295430183410645
# 40/40 [==============================] - 0s 428us/step
#
# outlier fraction MAPE: 0.0341
# nmad MAPE: 0.0248

# %% [markdown]
# # Part 3: Effect of learning rate schedules
#
# When training a neural network, we can tune the performance by optimizing a large set of hyperparameters. Last time, we looked at the choice of optimizer and regularization. Another important parameter is the learning rate. A learning rate that is set too small will slow down the training, as we update the weights of the network in tiny steps. On the other hand, if the learning rate is set too high, the training can diverge. Usually we want to start with a large learning rate to make fast progress and then slow down the training close to the optimum. This can be achieved by using learning rate schedules, which we will investigate in this exercise.

# %% [markdown]
# ## Step 1: Time based-decay
#
# First we can try a time-based decay:
# $$\eta(t)=\eta_0/(1+t⋅\eta_0/n_{epochs})$$
#
# where $\eta_0$ is the initial learning rate, $t$ the iteration number (epoch) and $n_{epochs}$ the total number of epochs.
#
# Write a function (i.e the learning schedule) that implements this learning schedule. The function takes an epoch index (integer, indexed from 0) and current learning rate (float) as inputs and returns a new learning rate as output (float). In our case, the current learning rate is not actually used in the function, but this format is expected when we use it in keras later. Set the initial learning rate to 0.001 and the number of epochs to 100. Make a plot of the learning rate as a function of epochs.

# %%
initial_lr = 0.001
n_epochs = 100

def time_based_decay(epoch, lr):
    return lr / (1 + epoch * lr / n_epochs)

learning_rates = [time_based_decay(epoch, initial_lr) for epoch in range(n_epochs)]

plt.plot(range(n_epochs), learning_rates)
plt.xlabel('epoch')
plt.ylabel('learning rate')
plt.title('time based decay')
plt.show()

# %% [markdown]
# Train the model with this new learning rate schedule, and save the history. Remember to rebuild the model to re-initialize all weights and biases. To use the learning rate schedule, add **callbacks=[keras.callbacks.LearningRateScheduler(my_function, verbose=1)]** to model.fit()

# %%
model = keras.Sequential([
    keras.layers.Dense(100, activation='relu', input_shape=(6,)),
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(1, activation='linear')
])

model.compile(optimizer=Adam(learning_rate=0.001), loss='MeanSquaredError')

history_time = model.fit(Xs_train, y_train,
                    epochs = 100,
                    batch_size = 300,
                    validation_data = (Xs_val, y_val),
                    callbacks=[keras.callbacks.LearningRateScheduler(time_based_decay, verbose=1)] )
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 1/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.4293 - val_loss: 0.2431 - lr: 0.0010
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.0009999900475965004.
# Epoch 2/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2073 - val_loss: 0.1371 - lr: 9.9999e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.000999970036578321.
# Epoch 3/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1182 - val_loss: 0.0829 - lr: 9.9997e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.0009999400150435445.
# Epoch 4/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0765 - val_loss: 0.0565 - lr: 9.9994e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.000999899983592717.
# Epoch 5/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0576 - val_loss: 0.0430 - lr: 9.9990e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.000999849942826272.
# Epoch 6/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0489 - val_loss: 0.0362 - lr: 9.9985e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.0009997900097458527.
# Epoch 7/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0461 - val_loss: 0.0328 - lr: 9.9979e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.000999720068545565.
# Epoch 8/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0443 - val_loss: 0.0311 - lr: 9.9972e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.0009996401198253202.
# Epoch 9/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0434 - val_loss: 0.0306 - lr: 9.9964e-04
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.0009995501641847956.
# Epoch 10/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0424 - val_loss: 0.0304 - lr: 9.9955e-04
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.0009994503186154574.
# Epoch 11/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0416 - val_loss: 0.0308 - lr: 9.9945e-04
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.0009993404673197235.
# Epoch 12/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0411 - val_loss: 0.0300 - lr: 9.9934e-04
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.0009992206108963915.
# Epoch 13/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0404 - val_loss: 0.0289 - lr: 9.9922e-04
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.0009990908663289882.
# Epoch 14/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0398 - val_loss: 0.0285 - lr: 9.9909e-04
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.0009989511178258468.
# Epoch 15/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0392 - val_loss: 0.0283 - lr: 9.9895e-04
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.0009988014823650582.
# Epoch 16/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0387 - val_loss: 0.0279 - lr: 9.9880e-04
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.0009986418441587468.
# Epoch 17/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0385 - val_loss: 0.0274 - lr: 9.9864e-04
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.0009984723201794522.
# Epoch 18/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0381 - val_loss: 0.0276 - lr: 9.9847e-04
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.0009982929110164556.
# Epoch 19/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0378 - val_loss: 0.0269 - lr: 9.9829e-04
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.0009981036172585127.
# Epoch 20/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0373 - val_loss: 0.0275 - lr: 9.9810e-04
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.0009979044394938241.
# Epoch 21/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0366 - val_loss: 0.0277 - lr: 9.9790e-04
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.0009976953783100069.
# Epoch 22/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0362 - val_loss: 0.0263 - lr: 9.9770e-04
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.0009974764342940642.
# Epoch 23/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0357 - val_loss: 0.0262 - lr: 9.9748e-04
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.000997247608032357.
# Epoch 24/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0357 - val_loss: 0.0260 - lr: 9.9725e-04
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.0009970090164701905.
# Epoch 25/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0357 - val_loss: 0.0277 - lr: 9.9701e-04
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.0009967605438283237.
# Epoch 26/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0353 - val_loss: 0.0256 - lr: 9.9676e-04
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.000996502307046025.
# Epoch 27/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0348 - val_loss: 0.0264 - lr: 9.9650e-04
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.0009962343066998891.
# Epoch 28/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0347 - val_loss: 0.0268 - lr: 9.9623e-04
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.0009959565433657347.
# Epoch 29/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0343 - val_loss: 0.0255 - lr: 9.9596e-04
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.0009956690176185742.
# Epoch 30/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0342 - val_loss: 0.0251 - lr: 9.9567e-04
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.0009953717300325861.
# Epoch 31/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0335 - val_loss: 0.0256 - lr: 9.9537e-04
#
# Epoch 32: LearningRateScheduler setting learning rate to 0.0009950646811810859.
# Epoch 32/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0338 - val_loss: 0.0266 - lr: 9.9506e-04
#
# Epoch 33: LearningRateScheduler setting learning rate to 0.0009947479879777168.
# Epoch 33/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0346 - val_loss: 0.0262 - lr: 9.9475e-04
#
# Epoch 34: LearningRateScheduler setting learning rate to 0.000994421534648184.
# Epoch 34/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0333 - val_loss: 0.0248 - lr: 9.9442e-04
#
# Epoch 35: LearningRateScheduler setting learning rate to 0.000994085438099691.
# Epoch 35/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0326 - val_loss: 0.0249 - lr: 9.9409e-04
#
# Epoch 36: LearningRateScheduler setting learning rate to 0.0009937396988949682.
# Epoch 36/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0325 - val_loss: 0.0244 - lr: 9.9374e-04
#
# Epoch 37: LearningRateScheduler setting learning rate to 0.000993384317595754.
# Epoch 37/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0321 - val_loss: 0.0244 - lr: 9.9338e-04
#
# Epoch 38: LearningRateScheduler setting learning rate to 0.0009930192947627703.
# Epoch 38/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0323 - val_loss: 0.0247 - lr: 9.9302e-04
#
# Epoch 39: LearningRateScheduler setting learning rate to 0.0009926447472832051.
# Epoch 39/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0319 - val_loss: 0.0253 - lr: 9.9264e-04
#
# Epoch 40: LearningRateScheduler setting learning rate to 0.000992260559383595.
# Epoch 40/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0323 - val_loss: 0.0245 - lr: 9.9226e-04
#
# Epoch 41: LearningRateScheduler setting learning rate to 0.0009918668479444127.
# Epoch 41/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0316 - val_loss: 0.0254 - lr: 9.9187e-04
#
# Epoch 42: LearningRateScheduler setting learning rate to 0.0009914636135152264.
# Epoch 42/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0315 - val_loss: 0.0242 - lr: 9.9146e-04
#
# Epoch 43: LearningRateScheduler setting learning rate to 0.0009910509729628926.
# Epoch 43/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0316 - val_loss: 0.0241 - lr: 9.9105e-04
#
# Epoch 44: LearningRateScheduler setting learning rate to 0.000990628810511715.
# Epoch 44/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0313 - val_loss: 0.0256 - lr: 9.9063e-04
#
# Epoch 45: LearningRateScheduler setting learning rate to 0.000990197243021672.
# Epoch 45/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0312 - val_loss: 0.0252 - lr: 9.9020e-04
#
# Epoch 46: LearningRateScheduler setting learning rate to 0.0009897562710308426.
# Epoch 46/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0307 - val_loss: 0.0241 - lr: 9.8976e-04
#
# Epoch 47: LearningRateScheduler setting learning rate to 0.0009893058950760764.
# Epoch 47/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0299 - val_loss: 0.0237 - lr: 9.8931e-04
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.0009888461156929663.
# Epoch 48/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0303 - val_loss: 0.0235 - lr: 9.8885e-04
#
# Epoch 49: LearningRateScheduler setting learning rate to 0.0009883769334158227.
# Epoch 49/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0299 - val_loss: 0.0239 - lr: 9.8838e-04
#
# Epoch 50: LearningRateScheduler setting learning rate to 0.00098789846508029.
# Epoch 50/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0299 - val_loss: 0.0237 - lr: 9.8790e-04
#
# Epoch 51: LearningRateScheduler setting learning rate to 0.0009874107112113062.
# Epoch 51/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0292 - val_loss: 0.0233 - lr: 9.8741e-04
#
# Epoch 52: LearningRateScheduler setting learning rate to 0.0009869136723324688.
# Epoch 52/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0292 - val_loss: 0.0231 - lr: 9.8691e-04
#
# Epoch 53: LearningRateScheduler setting learning rate to 0.0009864074652619335.
# Epoch 53/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0294 - val_loss: 0.0233 - lr: 9.8641e-04
#
# Epoch 54: LearningRateScheduler setting learning rate to 0.0009858920905138407.
# Epoch 54/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0288 - val_loss: 0.0235 - lr: 9.8589e-04
#
# Epoch 55: LearningRateScheduler setting learning rate to 0.000985367548600934.
# Epoch 55/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0289 - val_loss: 0.0232 - lr: 9.8537e-04
#
# Epoch 56: LearningRateScheduler setting learning rate to 0.0009848338400345329.
# Epoch 56/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0289 - val_loss: 0.0254 - lr: 9.8483e-04
#
# Epoch 57: LearningRateScheduler setting learning rate to 0.0009842909653245105.
# Epoch 57/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0284 - val_loss: 0.0234 - lr: 9.8429e-04
#
# Epoch 58: LearningRateScheduler setting learning rate to 0.000983739041264069.
# Epoch 58/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0283 - val_loss: 0.0239 - lr: 9.8374e-04
#
# Epoch 59: LearningRateScheduler setting learning rate to 0.0009831780683534693.
# Epoch 59/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0281 - val_loss: 0.0231 - lr: 9.8318e-04
#
# Epoch 60: LearningRateScheduler setting learning rate to 0.0009826080470914731.
# Epoch 60/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0283 - val_loss: 0.0231 - lr: 9.8261e-04
#
# Epoch 61: LearningRateScheduler setting learning rate to 0.000982029094253491.
# Epoch 61/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0283 - val_loss: 0.0229 - lr: 9.8203e-04
#
# Epoch 62: LearningRateScheduler setting learning rate to 0.0009814412103286063.
# Epoch 62/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0279 - val_loss: 0.0237 - lr: 9.8144e-04
#
# Epoch 63: LearningRateScheduler setting learning rate to 0.0009808443958043529.
# Epoch 63/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0273 - val_loss: 0.0230 - lr: 9.8084e-04
#
# Epoch 64: LearningRateScheduler setting learning rate to 0.0009802386511666913.
# Epoch 64/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0270 - val_loss: 0.0232 - lr: 9.8024e-04
#
# Epoch 65: LearningRateScheduler setting learning rate to 0.0009796240931693786.
# Epoch 65/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0268 - val_loss: 0.0242 - lr: 9.7962e-04
#
# Epoch 66: LearningRateScheduler setting learning rate to 0.000979000722288603.
# Epoch 66/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0276 - val_loss: 0.0234 - lr: 9.7900e-04
#
# Epoch 67: LearningRateScheduler setting learning rate to 0.0009783685389989339.
# Epoch 67/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0269 - val_loss: 0.0234 - lr: 9.7837e-04
#
# Epoch 68: LearningRateScheduler setting learning rate to 0.0009777276600361486.
# Epoch 68/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0274 - val_loss: 0.0236 - lr: 9.7773e-04
#
# Epoch 69: LearningRateScheduler setting learning rate to 0.0009770780858649936.
# Epoch 69/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0273 - val_loss: 0.0229 - lr: 9.7708e-04
#
# Epoch 70: LearningRateScheduler setting learning rate to 0.000976419816948553.
# Epoch 70/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0269 - val_loss: 0.0240 - lr: 9.7642e-04
#
# Epoch 71: LearningRateScheduler setting learning rate to 0.0009757529118764008.
# Epoch 71/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0265 - val_loss: 0.0225 - lr: 9.7575e-04
#
# Epoch 72: LearningRateScheduler setting learning rate to 0.0009750773711049919.
# Epoch 72/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0264 - val_loss: 0.0220 - lr: 9.7508e-04
#
# Epoch 73: LearningRateScheduler setting learning rate to 0.0009743933113411004.
# Epoch 73/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0260 - val_loss: 0.0233 - lr: 9.7439e-04
#
# Epoch 74: LearningRateScheduler setting learning rate to 0.0009737007330312794.
# Epoch 74/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0260 - val_loss: 0.0231 - lr: 9.7370e-04
#
# Epoch 75: LearningRateScheduler setting learning rate to 0.000972999636620351.
# Epoch 75/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0261 - val_loss: 0.0224 - lr: 9.7300e-04
#
# Epoch 76: LearningRateScheduler setting learning rate to 0.0009722900806741837.
# Epoch 76/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0258 - val_loss: 0.0224 - lr: 9.7229e-04
#
# Epoch 77: LearningRateScheduler setting learning rate to 0.0009715721237525997.
# Epoch 77/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0253 - val_loss: 0.0229 - lr: 9.7157e-04
#
# Epoch 78: LearningRateScheduler setting learning rate to 0.0009708458244093789.
# Epoch 78/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0255 - val_loss: 0.0224 - lr: 9.7085e-04
#
# Epoch 79: LearningRateScheduler setting learning rate to 0.0009701111830726574.
# Epoch 79/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0260 - val_loss: 0.0221 - lr: 9.7011e-04
#
# Epoch 80: LearningRateScheduler setting learning rate to 0.0009693682582873199.
# Epoch 80/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0246 - val_loss: 0.0262 - lr: 9.6937e-04
#
# Epoch 81: LearningRateScheduler setting learning rate to 0.0009686171085922051.
# Epoch 81/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0269 - val_loss: 0.0243 - lr: 9.6862e-04
#
# Epoch 82: LearningRateScheduler setting learning rate to 0.0009678577344036781.
# Epoch 82/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0249 - val_loss: 0.0222 - lr: 9.6786e-04
#
# Epoch 83: LearningRateScheduler setting learning rate to 0.0009670901942516564.
# Epoch 83/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0245 - val_loss: 0.0238 - lr: 9.6709e-04
#
# Epoch 84: LearningRateScheduler setting learning rate to 0.0009663145466600107.
# Epoch 84/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0246 - val_loss: 0.0219 - lr: 9.6631e-04
#
# Epoch 85: LearningRateScheduler setting learning rate to 0.0009655308501465704.
# Epoch 85/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0240 - val_loss: 0.0222 - lr: 9.6553e-04
#
# Epoch 86: LearningRateScheduler setting learning rate to 0.0009647391051108948.
# Epoch 86/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0240 - val_loss: 0.0218 - lr: 9.6474e-04
#
# Epoch 87: LearningRateScheduler setting learning rate to 0.000963939370061878.
# Epoch 87/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0238 - val_loss: 0.0223 - lr: 9.6394e-04
#
# Epoch 88: LearningRateScheduler setting learning rate to 0.000963131645392223.
# Epoch 88/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0237 - val_loss: 0.0222 - lr: 9.6313e-04
#
# Epoch 89: LearningRateScheduler setting learning rate to 0.0009623160477109881.
# Epoch 89/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0234 - val_loss: 0.0215 - lr: 9.6232e-04
#
# Epoch 90: LearningRateScheduler setting learning rate to 0.0009614925774008903.
# Epoch 90/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0232 - val_loss: 0.0226 - lr: 9.6149e-04
#
# Epoch 91: LearningRateScheduler setting learning rate to 0.0009606612929498127.
# Epoch 91/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0240 - val_loss: 0.0220 - lr: 9.6066e-04
#
# Epoch 92: LearningRateScheduler setting learning rate to 0.0009598221947335958.
# Epoch 92/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0231 - val_loss: 0.0216 - lr: 9.5982e-04
#
# Epoch 93: LearningRateScheduler setting learning rate to 0.0009589753993361693.
# Epoch 93/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0227 - val_loss: 0.0215 - lr: 9.5898e-04
#
# Epoch 94: LearningRateScheduler setting learning rate to 0.0009581209071234047.
# Epoch 94/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0227 - val_loss: 0.0221 - lr: 9.5812e-04
#
# Epoch 95: LearningRateScheduler setting learning rate to 0.0009572587765622188.
# Epoch 95/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0227 - val_loss: 0.0218 - lr: 9.5726e-04
#
# Epoch 96: LearningRateScheduler setting learning rate to 0.0009563890661135332.
# Epoch 96/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0228 - val_loss: 0.0222 - lr: 9.5639e-04
#
# Epoch 97: LearningRateScheduler setting learning rate to 0.000955511776131362.
# Epoch 97/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0225 - val_loss: 0.0213 - lr: 9.5551e-04
#
# Epoch 98: LearningRateScheduler setting learning rate to 0.000954626965067703.
# Epoch 98/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0223 - val_loss: 0.0235 - lr: 9.5463e-04
#
# Epoch 99: LearningRateScheduler setting learning rate to 0.0009537346913685769.
# Epoch 99/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0227 - val_loss: 0.0211 - lr: 9.5373e-04
#
# Epoch 100: LearningRateScheduler setting learning rate to 0.0009528350134740373.
# Epoch 100/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0219 - val_loss: 0.0217 - lr: 9.5284e-04

# %% [markdown]
# ## Step 2: Exponential decay
#
# Repeat Part 3 Step 1 for a different learning schedule that uses exponential decay,
#
# $$ \eta(t)=\eta_0⋅e^{−k⋅t},$$
#
# where $k$ is the decay rate. We can try k=0.01.

# %%
def exponential_decay(epoch, lr, k = 0.01):
    return lr * np.exp(- k * epoch)

learning_rates = [exponential_decay(epoch, initial_lr) for epoch in range(n_epochs)]

plt.plot(range(n_epochs), learning_rates)
plt.xlabel('epoch')
plt.ylabel('learning rate')
plt.title('exponential decay')
plt.show()

# %%
model = keras.Sequential([
    keras.layers.Dense(100, activation='relu', input_shape=(6,)),
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(1, activation='linear')
])

model.compile(optimizer=Adam(learning_rate=0.001), loss='MeanSquaredError')

history_exp = model.fit(Xs_train, y_train,
                    epochs = 100,
                    batch_size = 300,
                    validation_data = (Xs_val, y_val),
                    callbacks=[keras.callbacks.LearningRateScheduler(exponential_decay, verbose=1)] )
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 1/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.3207 - val_loss: 0.2089 - lr: 0.0010
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.0009900498807740119.
# Epoch 2/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1651 - val_loss: 0.1091 - lr: 9.9005e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.0009704456117452426.
# Epoch 3/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0948 - val_loss: 0.0658 - lr: 9.7045e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.000941764628677312.
# Epoch 4/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0625 - val_loss: 0.0439 - lr: 9.4176e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0009048375025330474.
# Epoch 5/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0511 - val_loss: 0.0368 - lr: 9.0484e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0008607080608821331.
# Epoch 6/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0481 - val_loss: 0.0343 - lr: 8.6071e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.0008105843314528067.
# Epoch 7/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0461 - val_loss: 0.0341 - lr: 8.1058e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0007557838332641591.
# Epoch 8/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0450 - val_loss: 0.0331 - lr: 7.5578e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.0006976763900339466.
# Epoch 9/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0437 - val_loss: 0.0325 - lr: 6.9768e-04
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.0006376282040389431.
# Epoch 10/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0428 - val_loss: 0.0319 - lr: 6.3763e-04
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.0005769498507825865.
# Epoch 11/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0422 - val_loss: 0.0315 - lr: 5.7695e-04
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.0005168513726577378.
# Epoch 12/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0415 - val_loss: 0.0309 - lr: 5.1685e-04
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.0004584060467129666.
# Epoch 13/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0411 - val_loss: 0.0305 - lr: 4.5841e-04
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.00040252425943459547.
# Epoch 14/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0408 - val_loss: 0.0308 - lr: 4.0252e-04
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.00034993777379094726.
# Epoch 15/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0406 - val_loss: 0.0301 - lr: 3.4994e-04
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.00030119422432327167.
# Epoch 16/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0402 - val_loss: 0.0301 - lr: 3.0119e-04
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.0002566607938363688.
# Epoch 17/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0398 - val_loss: 0.0298 - lr: 2.5666e-04
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.00021653568829847953.
# Epoch 18/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0397 - val_loss: 0.0296 - lr: 2.1654e-04
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.00018086580777855162.
# Epoch 19/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0394 - val_loss: 0.0296 - lr: 1.8087e-04
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.00014956863573197313.
# Epoch 20/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0392 - val_loss: 0.0294 - lr: 1.4957e-04
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.0001224564371992143.
# Epoch 21/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0391 - val_loss: 0.0295 - lr: 1.2246e-04
#
# Epoch 22: LearningRateScheduler setting learning rate to 9.926125542263692e-05.
# Epoch 22/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0390 - val_loss: 0.0293 - lr: 9.9261e-05
#
# Epoch 23: LearningRateScheduler setting learning rate to 7.965902300295268e-05.
# Epoch 23/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0389 - val_loss: 0.0293 - lr: 7.9659e-05
#
# Epoch 24: LearningRateScheduler setting learning rate to 6.329177192825543e-05.
# Epoch 24/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0388 - val_loss: 0.0293 - lr: 6.3292e-05
#
# Epoch 25: LearningRateScheduler setting learning rate to 4.978707176336311e-05.
# Epoch 25/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0388 - val_loss: 0.0293 - lr: 4.9787e-05
#
# Epoch 26: LearningRateScheduler setting learning rate to 3.877421025179057e-05.
# Epoch 26/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0388 - val_loss: 0.0293 - lr: 3.8774e-05
#
# Epoch 27: LearningRateScheduler setting learning rate to 2.9896916983381158e-05.
# Epoch 27/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0387 - val_loss: 0.0292 - lr: 2.9897e-05
#
# Epoch 28: LearningRateScheduler setting learning rate to 2.282269346767588e-05.
# Epoch 28/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0387 - val_loss: 0.0292 - lr: 2.2823e-05
#
# Epoch 29: LearningRateScheduler setting learning rate to 1.7249020078344573e-05.
# Epoch 29/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0387 - val_loss: 0.0292 - lr: 1.7249e-05
#
# Epoch 30: LearningRateScheduler setting learning rate to 1.2906813203139013e-05.
# Epoch 30/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0387 - val_loss: 0.0292 - lr: 1.2907e-05
#
# Epoch 31: LearningRateScheduler setting learning rate to 9.561602260850495e-06.
# Epoch 31/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 9.5616e-06
#
# Epoch 32: LearningRateScheduler setting learning rate to 7.012928164252009e-06.
# Epoch 32/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 7.0129e-06
#
# Epoch 33: LearningRateScheduler setting learning rate to 5.09243099301936e-06.
# Epoch 33/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 5.0924e-06
#
# Epoch 34: LearningRateScheduler setting learning rate to 3.661069442590366e-06.
# Epoch 34/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 3.6611e-06
#
# Epoch 35: LearningRateScheduler setting learning rate to 2.6058406291575896e-06.
# Epoch 35/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 2.6058e-06
#
# Epoch 36: LearningRateScheduler setting learning rate to 1.8363048089975121e-06.
# Epoch 36/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 1.8363e-06
#
# Epoch 37: LearningRateScheduler setting learning rate to 1.2811463992656767e-06.
# Epoch 37/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 1.2811e-06
#
# Epoch 38: LearningRateScheduler setting learning rate to 8.849318081617858e-07.
# Epoch 38/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 8.8493e-07
#
# Epoch 39: LearningRateScheduler setting learning rate to 6.05170713160754e-07.
# Epoch 39/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 6.0517e-07
#
# Epoch 40: LearningRateScheduler setting learning rate to 4.0973500026693855e-07.
# Epoch 40/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 4.0974e-07
#
# Epoch 41: LearningRateScheduler setting learning rate to 2.746535898194838e-07.
# Epoch 41/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 2.7465e-07
#
# Epoch 42: LearningRateScheduler setting learning rate to 1.8227392170319446e-07.
# Epoch 42/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 1.8227e-07
#
# Epoch 43: LearningRateScheduler setting learning rate to 1.1976250090224292e-07.
# Epoch 43/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 1.1976e-07
#
# Epoch 44: LearningRateScheduler setting learning rate to 7.790659800288687e-08.
# Epoch 44/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 7.7907e-08
#
# Epoch 45: LearningRateScheduler setting learning rate to 5.017468688037605e-08.
# Epoch 45/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 5.0175e-08
#
# Epoch 46: LearningRateScheduler setting learning rate to 3.199279325895796e-08.
# Epoch 46/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 3.1993e-08
#
# Epoch 47: LearningRateScheduler setting learning rate to 2.019652774724978e-08.
# Epoch 47/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 2.0197e-08
#
# Epoch 48: LearningRateScheduler setting learning rate to 1.2622875259794094e-08.
# Epoch 48/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 1.2623e-08
#
# Epoch 49: LearningRateScheduler setting learning rate to 7.810825524135104e-09.
# Epoch 49/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 7.8108e-09
#
# Epoch 50: LearningRateScheduler setting learning rate to 4.785118023373998e-09.
# Epoch 50/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 4.7851e-09
#
# Epoch 51: LearningRateScheduler setting learning rate to 2.902320825594304e-09.
# Epoch 51/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 2.9023e-09
#
# Epoch 52: LearningRateScheduler setting learning rate to 1.7428308255766993e-09.
# Epoch 52/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 1.7428e-09
#
# Epoch 53: LearningRateScheduler setting learning rate to 1.0361487695675697e-09.
# Epoch 53/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 1.0361e-09
#
# Epoch 54: LearningRateScheduler setting learning rate to 6.098822873173108e-10.
# Epoch 54/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 6.0988e-10
#
# Epoch 55: LearningRateScheduler setting learning rate to 3.554078510754607e-10.
# Epoch 55/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 3.5541e-10
#
# Epoch 56: LearningRateScheduler setting learning rate to 2.0505248707580387e-10.
# Epoch 56/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 2.0505e-10
#
# Epoch 57: LearningRateScheduler setting learning rate to 1.171278402115734e-10.
# Epoch 57/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 1.1713e-10
#
# Epoch 58: LearningRateScheduler setting learning rate to 6.623877039025003e-11.
# Epoch 58/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 6.6239e-11
#
# Epoch 59: LearningRateScheduler setting learning rate to 3.7086979917056545e-11.
# Epoch 59/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 3.7087e-11
#
# Epoch 60: LearningRateScheduler setting learning rate to 2.055832454597131e-11.
# Epoch 60/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 2.0558e-11
#
# Epoch 61: LearningRateScheduler setting learning rate to 1.1282647506775112e-11.
# Epoch 61/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 1.1283e-11
#
# Epoch 62: LearningRateScheduler setting learning rate to 6.130436356798962e-12.
# Epoch 62/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 6.1304e-12
#
# Epoch 63: LearningRateScheduler setting learning rate to 3.297834180918678e-12.
# Epoch 63/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 3.2978e-12
#
# Epoch 64: LearningRateScheduler setting learning rate to 1.7563994708712645e-12.
# Epoch 64/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 1.7564e-12
#
# Epoch 65: LearningRateScheduler setting learning rate to 9.261361480080676e-13.
# Epoch 65/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 9.2614e-13
#
# Epoch 66: LearningRateScheduler setting learning rate to 4.834854506312847e-13.
# Epoch 66/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 4.8349e-13
#
# Epoch 67: LearningRateScheduler setting learning rate to 2.4989008996680037e-13.
# Epoch 67/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 2.4989e-13
#
# Epoch 68: LearningRateScheduler setting learning rate to 1.278709015364088e-13.
# Epoch 68/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 1.2787e-13
#
# Epoch 69: LearningRateScheduler setting learning rate to 6.478157030837902e-14.
# Epoch 69/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 6.4782e-14
#
# Epoch 70: LearningRateScheduler setting learning rate to 3.249288407339105e-14.
# Epoch 70/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 3.2493e-14
#
# Epoch 71: LearningRateScheduler setting learning rate to 1.613548926807919e-14.
# Epoch 71/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 1.6135e-14
#
# Epoch 72: LearningRateScheduler setting learning rate to 7.932919910851546e-15.
# Epoch 72/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 7.9329e-15
#
# Epoch 73: LearningRateScheduler setting learning rate to 3.86136675589897e-15.
# Epoch 73/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 3.8614e-15
#
# Epoch 74: LearningRateScheduler setting learning rate to 1.8608272571528645e-15.
# Epoch 74/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 1.8608e-15
#
# Epoch 75: LearningRateScheduler setting learning rate to 8.878265515311439e-16.
# Epoch 75/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 8.8783e-16
#
# Epoch 76: LearningRateScheduler setting learning rate to 4.193795576207294e-16.
# Epoch 76/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 4.1938e-16
#
# Epoch 77: LearningRateScheduler setting learning rate to 1.9612974259018755e-16.
# Epoch 77/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 1.9613e-16
#
# Epoch 78: LearningRateScheduler setting learning rate to 9.081063167793916e-17.
# Epoch 78/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 9.0811e-17
#
# Epoch 79: LearningRateScheduler setting learning rate to 4.162814046364502e-17.
# Epoch 79/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 4.1628e-17
#
# Epoch 80: LearningRateScheduler setting learning rate to 1.8892714200063403e-17.
# Epoch 80/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 1.8893e-17
#
# Epoch 81: LearningRateScheduler setting learning rate to 8.489043701227853e-18.
# Epoch 81/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 8.4890e-18
#
# Epoch 82: LearningRateScheduler setting learning rate to 3.7764195229683045e-18.
# Epoch 82/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 3.7764e-18
#
# Epoch 83: LearningRateScheduler setting learning rate to 1.6632546741956909e-18.
# Epoch 83/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 1.6633e-18
#
# Epoch 84: LearningRateScheduler setting learning rate to 7.252610063572399e-19.
# Epoch 84/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 7.2526e-19
#
# Epoch 85: LearningRateScheduler setting learning rate to 3.1310280633996413e-19.
# Epoch 85/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 3.1310e-19
#
# Epoch 86: LearningRateScheduler setting learning rate to 1.338248131522028e-19.
# Epoch 86/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 1.3382e-19
#
# Epoch 87: LearningRateScheduler setting learning rate to 5.662958439414106e-20.
# Epoch 87/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 5.6630e-20
#
# Epoch 88: LearningRateScheduler setting learning rate to 2.372505281585403e-20.
# Epoch 88/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 2.3725e-20
#
# Epoch 89: LearningRateScheduler setting learning rate to 9.840746213717652e-21.
# Epoch 89/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 9.8407e-21
#
# Epoch 90: LearningRateScheduler setting learning rate to 4.041159125508344e-21.
# Epoch 90/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 4.0412e-21
#
# Epoch 91: LearningRateScheduler setting learning rate to 1.6430126293347544e-21.
# Epoch 91/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 1.6430e-21
#
# Epoch 92: LearningRateScheduler setting learning rate to 6.613523856822511e-22.
# Epoch 92/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 6.6135e-22
#
# Epoch 93: LearningRateScheduler setting learning rate to 2.635615271521663e-22.
# Epoch 93/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 2.6356e-22
#
# Epoch 94: LearningRateScheduler setting learning rate to 1.0398918091059363e-22.
# Epoch 94/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 1.0399e-22
#
# Epoch 95: LearningRateScheduler setting learning rate to 4.0621067530912115e-23.
# Epoch 95/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 4.0621e-23
#
# Epoch 96: LearningRateScheduler setting learning rate to 1.5709833036236237e-23.
# Epoch 96/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 1.5710e-23
#
# Epoch 97: LearningRateScheduler setting learning rate to 6.015183527550419e-24.
# Epoch 97/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 6.0152e-24
#
# Epoch 98: LearningRateScheduler setting learning rate to 2.2802540436274384e-24.
# Epoch 98/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 2.2803e-24
#
# Epoch 99: LearningRateScheduler setting learning rate to 8.558046782856612e-25.
# Epoch 99/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 8.5580e-25
#
# Epoch 100: LearningRateScheduler setting learning rate to 3.1799708836768617e-25.
# Epoch 100/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0292 - lr: 3.1800e-25

# %%
model = keras.Sequential([
    keras.layers.Dense(100, activation='relu', input_shape=(6,)),
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(1, activation='linear')
])

model.compile(optimizer=Adam(learning_rate=0.001), loss='MeanSquaredError')

history = model.fit(Xs_train, y_train,
                    epochs = 100,
                    batch_size = 300,
                    validation_data = (Xs_val, y_val))
# Out:
# Epoch 1/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.3471 - val_loss: 0.2149
# Epoch 2/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1776 - val_loss: 0.1119
# Epoch 3/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0946 - val_loss: 0.0627
# Epoch 4/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0618 - val_loss: 0.0431
# Epoch 5/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0504 - val_loss: 0.0356
# Epoch 6/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0463 - val_loss: 0.0320
# Epoch 7/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0440 - val_loss: 0.0309
# Epoch 8/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0422 - val_loss: 0.0315
# Epoch 9/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0412 - val_loss: 0.0297
# Epoch 10/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0401 - val_loss: 0.0291
# Epoch 11/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0395 - val_loss: 0.0292
# Epoch 12/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0291
# Epoch 13/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0386 - val_loss: 0.0280
# Epoch 14/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0373 - val_loss: 0.0280
# Epoch 15/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0366 - val_loss: 0.0269
# Epoch 16/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0362 - val_loss: 0.0268
# Epoch 17/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0360 - val_loss: 0.0275
# Epoch 18/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0356 - val_loss: 0.0265
# Epoch 19/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0354 - val_loss: 0.0267
# Epoch 20/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0346 - val_loss: 0.0261
# Epoch 21/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0341 - val_loss: 0.0252
# Epoch 22/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0337 - val_loss: 0.0258
# Epoch 23/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0337 - val_loss: 0.0260
# Epoch 24/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0334 - val_loss: 0.0247
# Epoch 25/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0331 - val_loss: 0.0244
# Epoch 26/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0327 - val_loss: 0.0245
# Epoch 27/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0323 - val_loss: 0.0246
# Epoch 28/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0319 - val_loss: 0.0253
# Epoch 29/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0325 - val_loss: 0.0258
# Epoch 30/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0326 - val_loss: 0.0241
# Epoch 31/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0313 - val_loss: 0.0241
# Epoch 32/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0308 - val_loss: 0.0242
# Epoch 33/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0308 - val_loss: 0.0240
# Epoch 34/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0302 - val_loss: 0.0240
# Epoch 35/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0302 - val_loss: 0.0236
# Epoch 36/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0301 - val_loss: 0.0238
# Epoch 37/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0297 - val_loss: 0.0232
# Epoch 38/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0297 - val_loss: 0.0238
# Epoch 39/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0297 - val_loss: 0.0242
# Epoch 40/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0293 - val_loss: 0.0233
# Epoch 41/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0295 - val_loss: 0.0250
# Epoch 42/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0294 - val_loss: 0.0231
# Epoch 43/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0286 - val_loss: 0.0238
# Epoch 44/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0287 - val_loss: 0.0248
# Epoch 45/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0284 - val_loss: 0.0233
# Epoch 46/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0280 - val_loss: 0.0231
# Epoch 47/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0279 - val_loss: 0.0228
# Epoch 48/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0279 - val_loss: 0.0224
# Epoch 49/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0274 - val_loss: 0.0231
# Epoch 50/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0274 - val_loss: 0.0237
# Epoch 51/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0275 - val_loss: 0.0231
# Epoch 52/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0276 - val_loss: 0.0233
# Epoch 53/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0269 - val_loss: 0.0239
# Epoch 54/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0268 - val_loss: 0.0225
# Epoch 55/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0269 - val_loss: 0.0230
# Epoch 56/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0270 - val_loss: 0.0235
# Epoch 57/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0268 - val_loss: 0.0229
# Epoch 58/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0261 - val_loss: 0.0232
# Epoch 59/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0264 - val_loss: 0.0237
# Epoch 60/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0264 - val_loss: 0.0221
# Epoch 61/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0260 - val_loss: 0.0230
# Epoch 62/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0254 - val_loss: 0.0222
# Epoch 63/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0255 - val_loss: 0.0222
# Epoch 64/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0254 - val_loss: 0.0225
# Epoch 65/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0257 - val_loss: 0.0252
# Epoch 66/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0268 - val_loss: 0.0237
# Epoch 67/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0268 - val_loss: 0.0225
# Epoch 68/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0256 - val_loss: 0.0227
# Epoch 69/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0243 - val_loss: 0.0224
# Epoch 70/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0247 - val_loss: 0.0230
# Epoch 71/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0242 - val_loss: 0.0219
# Epoch 72/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0242 - val_loss: 0.0220
# Epoch 73/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0240 - val_loss: 0.0225
# Epoch 74/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0240 - val_loss: 0.0221
# Epoch 75/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0236 - val_loss: 0.0230
# Epoch 76/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0240 - val_loss: 0.0219
# Epoch 77/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0236 - val_loss: 0.0220
# Epoch 78/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0235 - val_loss: 0.0221
# Epoch 79/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0233 - val_loss: 0.0215
# Epoch 80/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0231 - val_loss: 0.0225
# Epoch 81/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0233 - val_loss: 0.0218
# Epoch 82/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0233 - val_loss: 0.0220
# Epoch 83/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0228 - val_loss: 0.0215
# Epoch 84/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0224 - val_loss: 0.0214
# Epoch 85/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0221 - val_loss: 0.0216
# Epoch 86/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0226 - val_loss: 0.0211
# Epoch 87/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0225 - val_loss: 0.0212
# Epoch 88/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0219 - val_loss: 0.0208
# Epoch 89/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0219 - val_loss: 0.0215
# Epoch 90/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0219 - val_loss: 0.0208
# Epoch 91/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0218 - val_loss: 0.0213
# Epoch 92/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0226 - val_loss: 0.0219
# Epoch 93/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0224 - val_loss: 0.0217
# Epoch 94/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0214 - val_loss: 0.0212
# Epoch 95/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0214 - val_loss: 0.0218
# Epoch 96/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0213 - val_loss: 0.0210
# Epoch 97/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0214 - val_loss: 0.0214
# Epoch 98/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0211 - val_loss: 0.0220
# Epoch 99/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0210 - val_loss: 0.0208
# Epoch 100/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0209 - val_loss: 0.0206

# %% [markdown]
# ## Step 3:
#
# Graph the loss for the three learning schedules we have (constant, time decay, exponential decay). Zoom in on the values at the end of the training to better see the differences.

# %%
plt.plot(history.history['loss'], 'r-', label='train set constant')
plt.plot(history.history['val_loss'],'r--', label='validation set constant')


plt.plot(history_time.history['loss'], 'g-', label='train set time')
plt.plot(history_time.history['val_loss'], 'g--', label='validation set time')


plt.plot(history_exp.history['loss'], 'b-', label='train set exp')
plt.plot(history_exp.history['val_loss'], 'b--', label='validation set exp')

plt.xlabel('epoch')
plt.ylabel('mean squared error')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'], 'r-', label='train set constant')
plt.plot(history.history['val_loss'],'r--', label='validation set constant')


plt.plot(history_time.history['loss'], 'g-', label='train set time')
plt.plot(history_time.history['val_loss'], 'g--', label='validation set time')


plt.plot(history_exp.history['loss'], 'b-', label='train set exp')
plt.plot(history_exp.history['val_loss'], 'b--', label='validation set exp')

plt.xlabel('epoch')
plt.ylabel('mean squared error')
plt.legend()

plt.xlim([80,100])
plt.ylim([0,0.05])
plt.show()

# %% [markdown]
# # Part 4: A first convolutional neural network
#
# In the following, we try to improve on our dense NN for the MNIST image dataset with a deep convolutional network. There are two new kinds of layers that will be used, **Conv2D** and **MaxPool2D**. We will discuss this in detail next week, but for now just look at the code. While the code runs, try to figure out the structure of the network. You might want to look up these layers in the keras documentation.

# %%
(x_train, y_train),(x_test, y_test) = keras.datasets.mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0  

x_train = x_train.reshape(-1,28,28,1)
x_test = x_test.reshape(-1,28,28,1)

x_train, x_val, y_train, y_val = train_test_split(
	x_train, y_train, test_size = 1/6, random_state=42)

print('x_train.shape =', x_train.shape)
print('y_train.shape =', y_train.shape)
print('x_val.shape =', x_val.shape)
print('y_val.shape =', y_val.shape)
print('x_test.shape =', x_test.shape)
print('y_test.shape =', y_test.shape)

# %%
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D

def make_conv_model():
  model = Sequential()

  model.add(Conv2D(filters = 10, kernel_size = (5,5),padding = 'Same', 
                  activation ='relu', input_shape = (28,28,1)))
  model.add(Conv2D(filters = 10, kernel_size = (5,5),padding = 'Same', 
                  activation ='relu'))
  model.add(MaxPool2D(pool_size=(2,2)))
  model.add(Flatten())
  model.add(Dense(64, activation = "relu"))
  model.add(Dropout(0.2))
  model.add(Dense(10, activation = "softmax"))
  optimizer = keras.optimizers.Adam()

  model.compile(optimizer=optimizer,
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy']) 
  return model

def make_dense_model():
  model = Sequential()
  model.add(Flatten(input_shape = (28,28,1)))
  model.add(Dense(512, activation = "relu"))
  model.add(Dropout(0.2))
  model.add(Dense(256, activation = "relu"))
  model.add(Dropout(0.2))
  model.add(Dense(10, activation = "softmax"))
  optimizer = keras.optimizers.Adam()

  model.compile(optimizer=optimizer,
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy']) 
  return model

simple_conv_model = make_conv_model()
dense_model = make_dense_model()
simple_conv_model.summary()
dense_model.summary()

# %%
epochs = 40
batch_size = 86

simple_conv_history = simple_conv_model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_val, y_val), verbose=1)
dense_history = dense_model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_val, y_val),verbose=1)

# %%
simple_conv_test_loss, simple_conv_test_acc = simple_conv_model.evaluate(x_test, y_test)
dense_test_loss, dense_test_acc = dense_model.evaluate(x_test, y_test)

plt.plot(dense_history.history["accuracy"], "b--",label="dense training accuracy")
plt.plot(dense_history.history["val_accuracy"], "b-",label="dense val accuracy")
plt.axhline(dense_test_acc, color="k", linestyle=":", label="dense test accuracy")
plt.plot(simple_conv_history.history["accuracy"], "g--",label="simple conv training accuracy")
plt.plot(simple_conv_history.history["val_accuracy"], "g-",label="simple conv val accuracy")
plt.axhline(simple_conv_test_acc,color="k", linestyle="--", label="simple conv test accuracy")
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0.94, 1.005)
plt.legend()
